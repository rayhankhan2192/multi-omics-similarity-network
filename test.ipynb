# %%
import pandas as pd

# %%
df1 = pd.read_csv(r'E:\Python\Research\Mogonet\Label-1 (Hybrid) -optimized\MOGONET\ROSMAP\1_featname.csv')
df2 = pd.read_csv(r'E:\Python\Research\Mogonet\Label-1 (Hybrid) -optimized\MOGONET\ROSMAP\1_tr.csv')

# %%
df.head()  # Display the first few rows of the DataFrame
# Out:
#    1.813813162555837355e-01  1.253367340080431547e-01  \
# 0                  0.132848                  0.099462
# 1                  0.111206                  0.069999
# 2                  0.085876                  0.129139
# 3                  0.068125                  0.121434
# 4                  0.076376                  0.078149
#
#    9.480700062791144744e-02  4.802270308074692573e-01  \
# 0                  0.149573                  0.487058
# 1                  0.127883                  0.412276
# 2                  0.071849                  0.473626
# 3                  0.008678                  0.453002
# 4                  0.094807                  0.426190
#
#    2.461106265013439376e-01  3.702075043848315206e-01  \
# 0                  0.377940                  0.358607
# 1                  0.198039                  0.289383
# 2                  0.231430                  0.393466
# 3                  0.150118                  0.340528
# ...

# %%
import pandas as pd

# Load data
df1 = pd.read_csv(r'E:\Python\Research\Mogonet\Label-1 (Hybrid) -optimized\MOGONET\ROSMAP\1_featname.csv', header=None)
df2 = pd.read_csv(r'E:\Python\Research\Mogonet\Label-1 (Hybrid) -optimized\MOGONET\ROSMAP\1_tr.csv', header=None)

# Check the shape of both to ensure alignment
print(f"df1 shape (feature names): {df1.shape}")
print(f"df2 shape (feature matrix): {df2.shape}")

# Set column names of df2 using df1
df2.columns = df1[0].tolist()

# Now df2 has proper feature names
print(df2.head())
# Out:
# df1 shape (feature names): (200, 1)
# df2 shape (feature matrix): (245, 200)
#    ENSG00000161896.6  ENSG00000248714.2  ENSG00000242349.1  ENSG00000006831.9  \
# 0           0.181381           0.125337           0.094807           0.480227
# 1           0.132848           0.099462           0.149573           0.487058
# 2           0.111206           0.069999           0.127883           0.412276
# 3           0.085876           0.129139           0.071849           0.473626
# 4           0.068125           0.121434           0.008678           0.453002
#
#    ENSG00000261195.1  ENSG00000143409.11  ENSG00000140931.15  \
# 0           0.246111            0.370208            0.214085
# 1           0.377940            0.358607            0.300085
# 2           0.198039            0.289383            0.200385
# 3           0.231430            0.393466            0.184434
# 4           0.150118            0.340528            0.201158
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Example structure
data = [
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.877, "F1": 0.876, "AUC": 0.902},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.821, "F1": 0.819, "AUC": 0.863},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.892},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.858, "F1": 0.860, "AUC": 0.871},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.881},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.830, "F1": 0.820, "AUC": 0.886},
]

df = pd.DataFrame(data)

plt.figure(figsize=(10, 6))
sns.barplot(data=df, x="Method", y="Accuracy", hue="Dataset")
plt.title("Best Accuracy by Similarity Method")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
methods = ['Cosine Similarity', 'Cosine Distance', 'RBF Similarity', 'RBF Distance', 'Hybrid Distance', 'Hybrid Similarity']
acc = [0.877, 0.821, 0.849, 0.858, 0.830, 0.849]
f1 = [0.876, 0.819, 0.846, 0.860, 0.820, 0.846]
auc = [0.902, 0.869, 0.892, 0.871, 0.886, 0.881]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Original data
data = [
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.877, "F1": 0.876, "AUC": 0.902},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.821, "F1": 0.819, "AUC": 0.863},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.892},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.858, "F1": 0.860, "AUC": 0.871},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.881},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.830, "F1": 0.820, "AUC": 0.886},
]

df = pd.DataFrame(data)

# Melt for grouped bar plot
df_melted = df.melt(id_vars="Method", value_vars=["Accuracy", "F1", "AUC"], var_name="Metric", value_name="Score")

plt.figure(figsize=(12, 6))
import seaborn as sns
sns.barplot(data=df_melted, x="Method", y="Score", hue="Metric")
plt.xticks(rotation=45)
plt.title("ROSMAP: Accuracy, F1, AUC by Method")
plt.tight_layout()
plt.show()

# %%
import numpy as np
metrics = ["Accuracy", "F1", "AUC"]
angles = np.linspace(0, 2 * np.pi, len(metrics), endpoint=False).tolist()
angles += angles[:1]

# Log-linear transformation function
def log_transform(x, scale=10):
    return np.log10(1 + scale * x)

# Apply transformation to the values
plt.figure(figsize=(8, 8))
for d in data:
    values = [log_transform(d[m]) for m in metrics]
    values += values[:1]
    plt.polar(angles, values, label=d["Method"], linewidth=2)

plt.xticks(angles[:-1], metrics)
plt.title("ROSMAP: Metric Radar Chart (Log-Linear Scaled)", y=1.1)
plt.legend(loc='upper right', bbox_to_anchor=(1.3, 1.1))
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import pi
import matplotlib.ticker as ticker

# Original data
data = [
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.877, "F1": 0.876, "AUC": 0.902},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.821, "F1": 0.819, "AUC": 0.863},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.892},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.858, "F1": 0.860, "AUC": 0.871},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.881},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.830, "F1": 0.820, "AUC": 0.886},
]

df = pd.DataFrame(data)

# Radar chart setup
metrics = ['Accuracy', 'F1', 'AUC']
num_vars = len(metrics)
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
angles += angles[:1]  # close the circle

fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

# Plot each method
for _, row in df.iterrows():
    values = row[metrics].tolist()
    values += values[:1]
    ax.plot(angles, values, label=row["Method"])
    ax.fill(angles, values, alpha=0.1)

# Set up axis
ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)
ax.set_thetagrids(np.degrees(angles[:-1]), metrics)

# Custom radial ticks from 0.7 to 1.0
custom_ticks = np.arange(0.6, 1.01, 0.1)
ax.set_ylim(0.7, 1.0)
ax.set_yticks(custom_ticks)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f"{x:.2f}"))
ax.set_rlabel_position(180 / num_vars)

plt.title("ROSMAP")
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1.0))
plt.tight_layout()
plt.show()

# %%
def log_transform(x, scale=200):
    return np.log10(1 + scale * x)

# === Option B: Exponential Stretch ===
def stretch_transform(x, power=4):
    return x ** power

plt.figure(figsize=(8, 8))
for d in data:
    # Apply the transform here (choose one)
    values = [stretch_transform(d[m]) for m in metrics]
    # values = [log_transform(d[m]) for m in metrics]  # alternative

    values += values[:1]  # Close the circle
    plt.polar(angles, values, label=d["Method"], linewidth=2)

plt.xticks(angles[:-1], metrics)
plt.title("ROSMAP: Metric Radar Chart (Non-linear Scaled)", y=1.1)
plt.legend(loc='upper right', bbox_to_anchor=(1.3, 1.1))
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

methods = [d["Method"] for d in data]
metrics = ["Accuracy", "F1", "AUC"]
angles = np.linspace(0, 2 * np.pi, len(metrics), endpoint=False).tolist()
angles += angles[:1]

plt.figure(figsize=(8, 8))
for d in data:
    values = [d[m] for m in metrics]
    values += values[:1]  # Close the circle
    plt.polar(angles, values, label=d["Method"], linewidth=2)

plt.xticks(angles[:-1], metrics)
plt.title("ROSMAP: Metric Radar Chart per Method", y=1.1)
plt.legend(loc='upper right', bbox_to_anchor=(1.3, 1.1))
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

df_heatmap = df.set_index("Method")[["Accuracy", "F1", "AUC"]]
plt.figure(figsize=(8, 6))
sns.heatmap(df_heatmap, annot=True, cmap="YlGnBu", fmt=".3f")
plt.title("ROSMAP")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))
for metric in ["Accuracy", "F1", "AUC"]:
    plt.plot(df["Method"], df[metric], marker="o", label=metric)

plt.xticks(rotation=45)
plt.ylabel("Score")
plt.title("ROSMAP: Metric Trends by Method")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define data1 and data2
data1 = [ 
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.825, "F1 weighted": 0.817, "F1 macro": 0.766},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.783, "F1 weighted": 0.772, "F1 macro": 0.700},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.821, "F1 weighted": 0.810, "F1 macro": 0.745},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.764, "F1 weighted": 0.764, "F1 macro": 0.671},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.764, "F1 weighted": 0.753, "F1 macro": 0.685},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.776, "F1 weighted": 0.766, "F1 macro": 0.693},
]

data2 = [ 
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.877, "F1": 0.876, "AUC": 0.902},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.821, "F1": 0.819, "AUC": 0.863},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.892},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.858, "F1": 0.860, "AUC": 0.871},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.881},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.830, "F1": 0.820, "AUC": 0.886},
]

# Convert to DataFrames and melt
df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

df1_melted = df1.melt(id_vars="Method", value_vars=["Accuracy", "F1 weighted", "F1 macro"], 
                      var_name="Metric", value_name="Score")
df2_melted = df2.melt(id_vars="Method", value_vars=["Accuracy", "F1", "AUC"], 
                      var_name="Metric", value_name="Score")

# Plotting
fig, axes = plt.subplots(1, 2, figsize=(16, 6), sharey=True)

# Plot for data1
sns.lineplot(data=df1_melted, x="Metric", y="Score", hue="Method", marker="o", ax=axes[0])
axes[0].set_title("BRCA: Accuracy, F1 (weighted, macro)")
axes[0].grid(True)

# Plot for data2
sns.lineplot(data=df2_melted, x="Metric", y="Score", hue="Method", marker="o", ax=axes[1])
axes[1].set_title("ROSMAP: Accuracy, F1, AUC")
axes[1].grid(True)

plt.suptitle("Comparison: BRCA vs ROSMAP", fontsize=16)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Original data
data1 = [ 
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.825, "F1 weighted": 0.817, "F1 macro": 0.766},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.783, "F1 weighted": 0.772, "F1 macro": 0.700},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.821, "F1 weighted": 0.810, "F1 macro": 0.745},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.764, "F1 weighted": 0.764, "F1 macro": 0.671},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.764, "F1 weighted": 0.753, "F1 macro": 0.685},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.776, "F1 weighted": 0.766, "F1 macro": 0.693},
]

data2 = [ 
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.877, "F1": 0.876, "AUC": 0.902},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.821, "F1": 0.819, "AUC": 0.863},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.892},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.858, "F1": 0.860, "AUC": 0.871},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.881},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.830, "F1": 0.820, "AUC": 0.886},
]

# Convert to DataFrames and melt
df1 = pd.DataFrame(data1).melt(id_vars=["Method"], 
                                value_vars=["Accuracy", "F1 weighted", "F1 macro"], 
                                var_name="Metric", value_name="Score")
df1["Source"] = "data1"

df2 = pd.DataFrame(data2).melt(id_vars=["Method"], 
                                value_vars=["Accuracy", "F1", "AUC"], 
                                var_name="Metric", value_name="Score")
df2["Source"] = "data2"

# Combine both datasets
combined_df = pd.concat([df1, df2])

# Create a combined metric label that includes the source
combined_df["Metric (Source)"] = combined_df["Metric"] + " (" + combined_df["Source"] + ")"

# Plot
plt.figure(figsize=(14, 7))
sns.lineplot(data=combined_df, x="Metric (Source)", y="Score", hue="Method", style="Source", marker="o")

plt.title("Combined Line Chart: data1 and data2 Metrics Comparison")
plt.ylabel("Score")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Data
data = [
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.877, "F1": 0.876, "AUC": 0.902},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.821, "F1": 0.819, "AUC": 0.863},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.892},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.858, "F1": 0.860, "AUC": 0.871},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.881},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.830, "F1": 0.820, "AUC": 0.886},
]

df = pd.DataFrame(data)

# Melt into long format
df_melt = df.melt(id_vars=["Method"], value_vars=["Accuracy", "F1", "AUC"],
                  var_name="Metric", value_name="Value")

# Plot
plt.figure(figsize=(9, 6))
sns.stripplot(data=df_melt, x="Metric", y="Value", hue="Method", jitter=True, size=8)

# Customize
plt.title("Dot Matrix Plot (Strip Plot per Metric)", fontsize=14)
plt.ylim(0.7, 1.0)
plt.grid(True, linestyle='--', alpha=0.3)
plt.legend(loc='upper right', bbox_to_anchor=(1.25, 1.0), title="Method")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Data
data = [
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.877, "F1": 0.876, "AUC": 0.902},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.821, "F1": 0.819, "AUC": 0.863},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.892},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.858, "F1": 0.860, "AUC": 0.871},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.881},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.830, "F1": 0.820, "AUC": 0.886},
]

df = pd.DataFrame(data)

# Melt into long format
df_melt = df.melt(id_vars=["Method"], value_vars=["Accuracy", "F1", "AUC"],
                  var_name="Metric", value_name="Value")

# Plot Violin Plot
plt.figure(figsize=(9, 6))
sns.violinplot(data=df_melt, x="Metric", y="Value", inner="point", linewidth=1.2)

# Customize
plt.title("ROSMAP", fontsize=14)
plt.ylim(0.6, 1.0)
plt.grid(True, linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Original datasets
data1 = [ 
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.825, "F1 weighted": 0.817, "F1 macro": 0.766},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.783, "F1 weighted": 0.772, "F1 macro": 0.700},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.821, "F1 weighted": 0.810, "F1 macro": 0.745},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.764, "F1 weighted": 0.764, "F1 macro": 0.671},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.764, "F1 weighted": 0.753, "F1 macro": 0.685},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.776, "F1 weighted": 0.766, "F1 macro": 0.693},
]

data2 = [ 
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.877, "F1": 0.876, "AUC": 0.902},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.821, "F1": 0.819, "AUC": 0.863},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.892},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.858, "F1": 0.860, "AUC": 0.871},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.881},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.830, "F1": 0.820, "AUC": 0.886},
]

# Convert to DataFrames and melt
df1 = pd.DataFrame(data1).melt(id_vars="Method", 
                               value_vars=["Accuracy", "F1 weighted", "F1 macro"], 
                               var_name="Metric", value_name="Score")
df1["Metric"] = df1["Metric"] + " (BRCA)"

df2 = pd.DataFrame(data2).melt(id_vars="Method", 
                               value_vars=["Accuracy", "F1", "AUC"], 
                               var_name="Metric", value_name="Score")
df2["Metric"] = df2["Metric"] + " (ROSMAP)"

# Combine
combined = pd.concat([df1, df2], ignore_index=True)

# Plot
plt.figure(figsize=(16, 8))
sns.barplot(data=combined, x="Method", y="Score", hue="Metric", ci=None, palette="tab20")

plt.title("Comparison of Metrics by Method and Dataset Source", fontsize=15)
plt.xticks(rotation=45)
plt.ylabel("Score")
plt.xlabel("Method")
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\rrayh\AppData\Local\Temp\ipykernel_10228\4047674993.py:40: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=combined, x="Method", y="Score", hue="Metric", ci=None, palette="tab20")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Data
data1 = [ 
    {"Dataset": "BRCA", "Method": "Cosine Similarity", "Accuracy": 0.825, "F1 weighted": 0.817, "F1 macro": 0.766},
    {"Dataset": "BRCA", "Method": "Cosine Distance", "Accuracy": 0.783, "F1 weighted": 0.772, "F1 macro": 0.700},
    {"Dataset": "BRCA", "Method": "RBF Similarity", "Accuracy": 0.821, "F1 weighted": 0.810, "F1 macro": 0.745},
    {"Dataset": "BRCA", "Method": "RBF Distance", "Accuracy": 0.764, "F1 weighted": 0.764, "F1 macro": 0.671},
    {"Dataset": "BRCA", "Method": "Hybrid Similarity", "Accuracy": 0.764, "F1 weighted": 0.753, "F1 macro": 0.685},
    {"Dataset": "BRCA", "Method": "Hybrid Distance", "Accuracy": 0.776, "F1 weighted": 0.766, "F1 macro": 0.693},
]

data2 = [ 
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.877, "F1": 0.876, "AUC": 0.902},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.821, "F1": 0.819, "AUC": 0.863},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.892},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.858, "F1": 0.860, "AUC": 0.871},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.881},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.830, "F1": 0.820, "AUC": 0.886},
]

# Prepare DataFrames
df1 = pd.DataFrame(data1).melt(
    id_vars=["Dataset", "Method"], 
    value_vars=["Accuracy", "F1 weighted", "F1 macro"], 
    var_name="Metric", value_name="Score"
)
df1["Metric"] = "BRCA - " + df1["Metric"]

df2 = pd.DataFrame(data2).melt(
    id_vars=["Dataset", "Method"], 
    value_vars=["Accuracy", "F1", "AUC"], 
    var_name="Metric", value_name="Score"
)
df2["Metric"] = "ROSMAP - " + df2["Metric"]

# Combine
combined = pd.concat([df1, df2], ignore_index=True)

# Set the aesthetic style
sns.set(style="whitegrid", font_scale=1.1)

# Plot
plt.figure(figsize=(16, 9))
ax = sns.barplot(data=combined, x="Method", y="Score", hue="Metric", palette="tab20", ci=None)

# Annotate bar values
for bar in ax.patches:
    height = bar.get_height()
    if not pd.isna(height):
        ax.annotate(f'{height:.2f}', 
                    (bar.get_x() + bar.get_width() / 2, height), 
                    ha='center', va='bottom', fontsize=8, color='black')

# Tweak appearance
plt.title("Performance Comparison", fontsize=18, weight='bold')
plt.xlabel("Method", fontsize=14)
plt.ylabel("Score", fontsize=14)
plt.xticks(rotation=30, ha='right')
plt.legend(bbox_to_anchor=(1.01, 1), loc='upper left', title="Metric", fontsize=10, title_fontsize=11)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\rrayh\AppData\Local\Temp\ipykernel_10228\1548360982.py:47: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(data=combined, x="Method", y="Score", hue="Metric", palette="tab20", ci=None)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Data
data1 = [ 
    {"Dataset": "BRCA", "Method": "Cosine Similarity", "Accuracy": 0.825, "F1 weighted": 0.817, "F1 macro": 0.766},
    {"Dataset": "BRCA", "Method": "Cosine Distance", "Accuracy": 0.783, "F1 weighted": 0.772, "F1 macro": 0.700},
    {"Dataset": "BRCA", "Method": "RBF Similarity", "Accuracy": 0.821, "F1 weighted": 0.810, "F1 macro": 0.745},
    {"Dataset": "BRCA", "Method": "RBF Distance", "Accuracy": 0.764, "F1 weighted": 0.764, "F1 macro": 0.671},
    {"Dataset": "BRCA", "Method": "Hybrid Similarity", "Accuracy": 0.764, "F1 weighted": 0.753, "F1 macro": 0.685},
    {"Dataset": "BRCA", "Method": "Hybrid Distance", "Accuracy": 0.776, "F1 weighted": 0.766, "F1 macro": 0.693},
]

data2 = [ 
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.877, "F1": 0.876, "AUC": 0.902},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.821, "F1": 0.819, "AUC": 0.863},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.892},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.858, "F1": 0.860, "AUC": 0.871},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.881},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.830, "F1": 0.820, "AUC": 0.886},
]

# Prepare data
df1 = pd.DataFrame(data1).melt(id_vars="Method", 
                               value_vars=["Accuracy", "F1 weighted", "F1 macro"], 
                               var_name="Metric", value_name="Score")
df1["Source"] = "BRCA"

df2 = pd.DataFrame(data2).melt(id_vars="Method", 
                               value_vars=["Accuracy", "F1", "AUC"], 
                               var_name="Metric", value_name="Score")
df2["Source"] = "ROSMAP"

combined = pd.concat([df1, df2], ignore_index=True)
combined["Metric"] = combined["Metric"].astype(str)
combined["Method"] = combined["Method"].astype(str)

# Create combined label for better distinction
combined["Method_Source"] = combined["Method"] + " (" + combined["Source"] + ")"

# Plot
plt.figure(figsize=(16, 9))
sns.set_style("whitegrid")
barplot = sns.barplot(
    data=combined,
    x="Method",
    y="Score",
    hue="Metric",
    ci=None,
    palette="Set2"
)

# Add markers for Source (circle vs square)
markers = {"BRCA": "o", "ROSMAP": "s"}
for i, row in combined.iterrows():
    xloc = list(combined["Method"].unique()).index(row["Method"])
    hue_index = list(combined["Metric"].unique()).index(row["Metric"])
    xpos = xloc - 0.3 + hue_index * 0.2
    plt.plot(xpos, row["Score"], 
             marker=markers[row["Source"]],
             color='black',
             markersize=6,
             alpha=0.8)

# Annotate bar values
for bar in barplot.patches:
    height = bar.get_height()
    if height > 0:
        barplot.annotate(f'{height:.2f}', 
                         (bar.get_x() + bar.get_width() / 2, height),
                         ha='center', va='bottom', fontsize=8, color='black')

plt.title("Combined Metrics Comparison with Source Distinction", fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.legend(title="Metric", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\rrayh\AppData\Local\Temp\ipykernel_10228\2000347305.py:45: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   barplot = sns.barplot(

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Original datasets
data1 = [ 
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.825, "F1 weighted": 0.817, "F1 macro": 0.766},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.783, "F1 weighted": 0.772, "F1 macro": 0.700},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.821, "F1 weighted": 0.810, "F1 macro": 0.745},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.764, "F1 weighted": 0.764, "F1 macro": 0.671},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.764, "F1 weighted": 0.753, "F1 macro": 0.685},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.776, "F1 weighted": 0.766, "F1 macro": 0.693},
]

data2 = [ 
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.877, "F1": 0.876, "AUC": 0.902},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.821, "F1": 0.819, "AUC": 0.863},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.892},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.858, "F1": 0.860, "AUC": 0.871},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.881},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.830, "F1": 0.820, "AUC": 0.886},
]

# Convert to DataFrame and melt
df1 = pd.DataFrame(data1).melt(id_vars="Method", value_vars=["Accuracy", "F1 weighted", "F1 macro"], 
                               var_name="Metric", value_name="Score")
df1["Source"] = "BRCA"

df2 = pd.DataFrame(data2).melt(id_vars="Method", value_vars=["Accuracy", "F1", "AUC"], 
                               var_name="Metric", value_name="Score")
df2["Source"] = "ROSMAP"

# Combine and clean
combined = pd.concat([df1, df2], ignore_index=True)
combined["Metric"] = combined["Metric"].astype(str).str.strip()
combined["Method"] = combined["Method"].astype(str)

# Use different colors for different sources
palette = {
    'BRCA': 'skyblue',
    'ROSMAP': 'salmon'
}

# Plot
plt.figure(figsize=(16, 9))
sns.barplot(
    data=combined, x="Method", y="Score",
    hue="Source", palette=palette,
    ci=None, edgecolor="black"
)

# Add dots for each metric type
sns.stripplot(
    data=combined, x="Method", y="Score",
    hue="Metric", dodge=True, marker="D",
    alpha=0.6, size=6, linewidth=0.5
)

plt.title("Comparison of Metrics Across Methods and Sources", fontsize=16)
plt.xticks(rotation=45)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\rrayh\AppData\Local\Temp\ipykernel_10228\1322999690.py:46: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(

# %%
g = sns.FacetGrid(combined, col="Metric", hue="Source", sharey=False, height=4, aspect=1.5)
g.map(sns.lineplot, "Method", "Score", marker="o")
g.map(sns.scatterplot, "Method", "Score", s=100, edgecolor="black")
g.add_legend()
for ax in g.axes.flat:
    for label in ax.get_xticklabels():
        label.set_rotation(45)
g.fig.subplots_adjust(top=0.85)
g.fig.suptitle("Facet Comparison of Metrics from data1 and data2")
plt.show()

# %%
# Pivot for heatmaps
pivot1 = df1.pivot(index="Method", columns="Metric", values="Score")
pivot2 = df2.pivot(index="Method", columns="Metric", values="Score")

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

sns.heatmap(pivot1, annot=True, fmt=".3f", cmap="Blues", ax=axes[0])
axes[0].set_title("data1 Metrics Heatmap")

sns.heatmap(pivot2, annot=True, fmt=".3f", cmap="Greens", ax=axes[1])
axes[1].set_title("data2 Metrics Heatmap")

plt.suptitle("Heatmap Comparison of Method Performance")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 7
#       3 pivot2 = df2.pivot(index="Method", columns="Metric", values="Score")
#       5 fig, axes = plt.subplots(1, 2, figsize=(14, 6))
# ----> 7 sns.heatmap(pivot1, annot=True, fmt=".3f", cmap="Blues", ax=axes[0])
#       8 axes[0].set_title("data1 Metrics Heatmap")
#      10 sns.heatmap(pivot2, annot=True, fmt=".3f", cmap="Greens", ax=axes[1])
#
# File e:\Python\Research\Mogonet\Label-1 (Hybrid) -optimized\venv\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)    443
#     444 """
# ...

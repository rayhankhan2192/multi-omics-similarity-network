# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['Crack', 'Pothole', 'Surface Erosion']
precision = [0.96,0.91,0.91]
recall =    [0.93,0.93,0.93]
f1_score =  [0.95,0.92,0.92]

x = np.arange(len(categories))  # label locations
width = 0.25  # width of the bars

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar(x - width, precision, width, label='Precision', color='royalblue')
bars2 = ax.bar(x, recall, width, label='Recall', color='darkorange')
bars3 = ax.bar(x + width, f1_score, width, label='F1-score', color='gray')

# Add text labels on top of bars
for bar_group in [bars1, bars2, bars3]:
    for bar in bar_group:
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01, f"{bar.get_height():.2f}", ha='center')

# Labels and formatting
ax.set_ylabel('Classification Probability')
ax.set_title('Classification Report : CNN')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.set_ylim(0, 1.1)
ax.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['Crack', 'Pothole', 'Surface Erosion']
precision = [0.98,0.98,0.96]
recall =    [0.98,0.98,0.96]
f1_score =  [0.98,0.98,0.96]

x = np.arange(len(categories))  # label locations
width = 0.25  # width of the bars

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar(x - width, precision, width, label='Precision', color='royalblue')
bars2 = ax.bar(x, recall, width, label='Recall', color='darkorange')
bars3 = ax.bar(x + width, f1_score, width, label='F1-score', color='gray')

# Add text labels on top of bars
for bar_group in [bars1, bars2, bars3]:
    for bar in bar_group:
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01, f"{bar.get_height():.2f}", ha='center')

# Labels and formatting
ax.set_ylabel('Classification Probability')
ax.set_title('Classification Report : MOBILENETV2')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.set_ylim(0, 1.1)
ax.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['Crack', 'Pothole', 'Surface Erosion']
precision = [0.83,0.91,0.72]
recall =    [0.90,0.80,0.73]
f1_score =  [0.87,0.85,0.73]

x = np.arange(len(categories))  # label locations
width = 0.25  # width of the bars

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar(x - width, precision, width, label='Precision', color='royalblue')
bars2 = ax.bar(x, recall, width, label='Recall', color='darkorange')
bars3 = ax.bar(x + width, f1_score, width, label='F1-score', color='gray')

# Add text labels on top of bars
for bar_group in [bars1, bars2, bars3]:
    for bar in bar_group:
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01, f"{bar.get_height():.2f}", ha='center')

# Labels and formatting
ax.set_ylabel('Classification Probability')
ax.set_title('Classification Report : VGG19')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.set_ylim(0, 1.1)
ax.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['Crack', 'Pothole', 'Surface Erosion']
precision = [0.91,0.75,0.51]
recall =    [0.75,0.67,0.68]
f1_score =  [0.82,0.71,0.58]
x = np.arange(len(categories))  # label locations
width = 0.25  # width of the bars

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar(x - width, precision, width, label='Precision', color='royalblue')
bars2 = ax.bar(x, recall, width, label='Recall', color='darkorange')
bars3 = ax.bar(x + width, f1_score, width, label='F1-score', color='gray')

# Add text labels on top of bars
for bar_group in [bars1, bars2, bars3]:
    for bar in bar_group:
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01, f"{bar.get_height():.2f}", ha='center')

# Labels and formatting
ax.set_ylabel('Classification Probability')
ax.set_title('Classification Report : RESNET50')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.set_ylim(0, 1.1)
ax.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['Crack', 'Pothole', 'Surface Erosion']
precision = [0.55,0.00,0.53]
recall =    [0.65,0.00,0.89]
f1_score =  [0.59,0.00,0.67]

x = np.arange(len(categories))  # label locations
width = 0.25  # width of the bars

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar(x - width, precision, width, label='Precision', color='royalblue')
bars2 = ax.bar(x, recall, width, label='Recall', color='darkorange')
bars3 = ax.bar(x + width, f1_score, width, label='F1-score', color='gray')

# Add text labels on top of bars
for bar_group in [bars1, bars2, bars3]:
    for bar in bar_group:
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01, f"{bar.get_height():.2f}", ha='center')

# Labels and formatting
ax.set_ylabel('Classification Probability')
ax.set_title('Classification Report : EFFICIENTNET')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.set_ylim(0, 1.1)
ax.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Categories and dataset splits
categories = ['Crack', 'Pothole', 'Surface Erosion']
training_counts = [np.floor(465*0.8), np.floor(405*0.8), np.floor(414*0.8)]
testing_counts = [np.floor(465*0.1), np.floor(405*0.1), np.floor(414*0.1)]
validation_counts = [np.floor(465*0.1), np.floor(405*0.1), np.floor(414*0.1)]


x = np.arange(len(categories))  # label locations
width = 0.25  # width of the bars

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar(x - width, training_counts, width, label='Training 80%')
bars2 = ax.bar(x, testing_counts, width, label='Testing 10%')
bars3 = ax.bar(x + width, validation_counts, width, label='Validation 10%')

# Add text labels on top of bars
for bar_group in [bars1, bars2, bars3]:
    for bar in bar_group:
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 10, str(bar.get_height()), ha='center')

# Labels and formatting
ax.set_ylabel('Number of Images')
ax.set_title('Dataset Distribution Total: 1284')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Categories and dataset splits
categories = ['ROSMAP', 'BRCA']
training_counts = [np.floor(245), np.floor(612)]
testing_counts = [np.floor(106), np.floor(263)]



x = np.arange(len(categories))  # label locations
width = 0.25  # width of the bars

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar(x - width, training_counts, width, label='Training')
bars2 = ax.bar(x, testing_counts, width, label='Testing')


# Add text labels on top of bars
for bar_group in [bars1, bars2]:
    for bar in bar_group:
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 10, str(bar.get_height()), ha='center')

# Labels and formatting
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Categories and dataset splits
categories = ['ROSMAP', 'BRCA']
training_counts = [int(np.floor(245)), int(np.floor(612))]
testing_counts = [int(np.floor(106)), int(np.floor(263))]

# Function to show both percentage and count on pie slices
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        count = int(round(pct * total / 100.0))
        return f'{pct:.1f}%\n({count})'
    return my_autopct

# Plotting two pie charts: one for each category
fig, axes = plt.subplots(1, 2, figsize=(14, 7))

for i, ax in enumerate(axes):
    data = [training_counts[i], testing_counts[i]]
    labels = ['Training', 'Testing']
    colors = ['#66b3ff', '#ff9999']
    ax.pie(data, labels=labels, autopct=make_autopct(data), startangle=90, colors=colors)
    ax.set_title(f'{categories[i]} Dataset Split')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Categories and dataset splits
categories = ['ROSMAP', 'BRCA']
training_counts = [int(np.floor(245)), int(np.floor(612))]
testing_counts = [int(np.floor(106)), int(np.floor(263))]

x = np.arange(len(categories))
bar_width = 0.5

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Stacked bars
train_bars = ax.bar(x, training_counts, bar_width, label='Training', color='#66b3ff')
test_bars = ax.bar(x, testing_counts, bar_width, bottom=training_counts, label='Testing', color='#ff9999')

# Add text labels
for i in range(len(categories)):
    ax.text(x[i], training_counts[i]/2, f'{training_counts[i]}', ha='center', va='center', color='black')
    ax.text(x[i], training_counts[i] + testing_counts[i]/2, f'{testing_counts[i]}', ha='center', va='center', color='black')

# Labels and formatting
ax.set_ylabel('Number of Samples')
ax.set_title('Dataset Split by Category')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['ROSMAP', 'BRCA']
ACC = [0.877,0.825]
f1_score =  [0.876,0.817]
AUC =    [0.902,0.766]

x = np.arange(len(categories))  # label locations
width = 0.25  # width of the bars

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar(x - width, ACC, width, label='ACC', color='royalblue')
bars2 = ax.bar(x + width, f1_score, width, label='F1-score', color='gray')
bars3 = ax.bar(x, AUC, width, label='AUC', color='darkorange')

# Add text labels on top of bars
for bar_group in [bars1, bars2, bars3]:
    for bar in bar_group:
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01, f"{bar.get_height():.2f}", ha='center')

# Labels and formatting
ax.set_ylabel('Classification Probability')
ax.set_title('Classification Report : Cosine Similarity')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.set_ylim(0, 1.1)
ax.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datasets
datasets = ['ROSMAP', 'BRCA']

# Omics types
omics = ['mRNA', 'meth', 'miRNA']

# Total number of features [mRNA, meth, miRNA]
total_features = {
    'ROSMAP': [55889, 23788, 309],
    'BRCA': [20531, 20106, 503]
}

# Training features [mRNA, meth, miRNA]
training_features = {
    'ROSMAP': [200, 200, 200],
    'BRCA': [1000, 1000, 503]
}

x = np.arange(len(datasets))  # label locations
width = 0.25  # width of the bars

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Offsets for grouped bars
for i, omic in enumerate(omics):
    total_vals = [total_features[ds][i] for ds in datasets]
    train_vals = [training_features[ds][i] for ds in datasets]
    
    ax.bar(x + i * width - width, total_vals, width, label=f'{omic} - Total', alpha=0.7)
    ax.bar(x + i * width, train_vals, width, label=f'{omic} - Training')

# Formatting
ax.set_ylabel('Number of Features')
ax.set_title('Total vs Training Features in ROSMAP and BRCA')
ax.set_xticks(x + width / 2)
ax.set_xticklabels(datasets)
ax.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Dataset sample counts
datasets = ['ROSMAP', 'BRCA']
rosmap_classes = ['NC', 'AD']
rosmap_counts = [169, 182]

brca_classes = ['Normal-like', 'Basal-like', 'HER2-enriched', 'Luminal A', 'Luminal B']
brca_counts = [115, 131, 46, 436, 147]

fig, axs = plt.subplots(1, 2, figsize=(14, 6))

# ROSMAP bar plot
axs[0].bar(rosmap_classes, rosmap_counts, color='#66b3ff')
axs[0].set_title('ROSMAP Category Distribution')
axs[0].set_ylabel('Number of Samples')

# BRCA bar plot
axs[1].bar(brca_classes, brca_counts, color='#fc8d62')
axs[1].set_title('BRCA Category Distribution')
axs[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %%
import numpy as np

datasets = ['ROSMAP', 'BRCA']
omics = ['mRNA', 'meth', 'miRNA']
total_features = {
    'ROSMAP': [55889, 23788, 309],
    'BRCA': [20531, 20106, 503]
}

x = np.arange(len(datasets))
width = 0.25

fig, ax = plt.subplots(figsize=(10, 6))

for i, omic in enumerate(omics):
    values = [total_features[ds][i] for ds in datasets]
    ax.bar(x + i * width - width, values, width, label=omic)

ax.set_title('Total Number of Features by Omics Type')
ax.set_ylabel('Number of Features')
ax.set_xticks(x)
ax.set_xticklabels(datasets)
ax.legend()
plt.tight_layout()
plt.show()

# %%
training_features = {
    'ROSMAP': [200, 200, 200],
    'BRCA': [1000, 1000, 503]
}

fig, ax = plt.subplots(figsize=(10, 6))

for i, omic in enumerate(omics):
    values = [training_features[ds][i] for ds in datasets]
    ax.bar(x + i * width - width, values, width, label=omic)

ax.set_title('Number of Training Features by Omics Type')
ax.set_ylabel('Training Features')
ax.set_xticks(x)
ax.set_xticklabels(datasets)
ax.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Dataset sample counts
datasets = ['ROSMAP', 'BRCA']
rosmap_classes = ['NC', 'AD']
rosmap_counts = [169, 182]

brca_classes = ['Normal-like', 'Basal-like', 'HER2-enriched', 'Luminal A', 'Luminal B']
brca_counts = [115, 131, 46, 436, 147]

fig, axs = plt.subplots(1, 2, figsize=(14, 6))

# ROSMAP
bars1 = axs[0].bar(rosmap_classes, rosmap_counts, color='#66b3ff')
axs[0].set_title('ROSMAP Category Distribution')
axs[0].set_ylabel('Number of Samples')
for bar in bars1:
    axs[0].text(bar.get_x() + bar.get_width()/2, bar.get_height() + 3, str(bar.get_height()), ha='center', va='bottom')

# BRCA
bars2 = axs[1].bar(brca_classes, brca_counts, color='#fc8d62')
axs[1].set_title('BRCA Category Distribution')
axs[1].tick_params(axis='x', rotation=45)
for bar in bars2:
    axs[1].text(bar.get_x() + bar.get_width()/2, bar.get_height() + 5, str(bar.get_height()), ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Prepare data for heatmap
data = {
    'NC': [169, 0],
    'AD': [182, 0],
    'Normal-like': [0, 115],
    'Basal-like': [0, 131],
    'HER2-enriched': [0, 46],
    'Luminal A': [0, 436],
    'Luminal B': [0, 147]
}
datasets = ['ROSMAP', 'BRCA']

# Create DataFrame
df = pd.DataFrame(data, index=datasets)

# Plot heatmap
plt.figure(figsize=(10, 5))
sns.heatmap(df, annot=True, fmt='d', cmap='YlOrRd', linewidths=.5, cbar_kws={'label': 'Sample Count'})

plt.title('Sample Counts per Class in ROSMAP and BRCA')
plt.xlabel('Class')
plt.ylabel('Dataset')
plt.tight_layout()
plt.show()

# %%
import numpy as np

datasets = ['ROSMAP', 'BRCA']
omics = ['mRNA', 'meth', 'miRNA']
total_features = {
    'ROSMAP': [55889, 23788, 309],
    'BRCA': [20531, 20106, 503]
}

x = np.arange(len(datasets))
width = 0.25

fig, ax = plt.subplots(figsize=(10, 6))

for i, omic in enumerate(omics):
    values = [total_features[ds][i] for ds in datasets]
    bars = ax.bar(x + i * width - width, values, width, label=omic)
    for bar in bars:
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 800, str(bar.get_height()), ha='center', va='bottom')

ax.set_title('Total Number of Features by Omics Type')
ax.set_ylabel('Number of Features')
ax.set_xticks(x)
ax.set_xticklabels(datasets)
ax.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Prepare the data
total_features = {
    'ROSMAP': [55889, 23788, 309],
    'BRCA': [20531, 20106, 503]
}
omics = ['mRNA', 'meth', 'miRNA']

# Create DataFrame
df = pd.DataFrame(total_features, index=omics).T

# Plot heatmap
plt.figure(figsize=(8, 5))
sns.heatmap(df, annot=True, fmt='d', cmap='BuPu', linewidths=0.5, cbar_kws={'label': 'Number of Features'})

plt.title('Total Number of Features by Omics Type')
plt.xlabel('Omics Type')
plt.ylabel('Dataset')
plt.tight_layout()
plt.show()

# %%
training_features = {
    'ROSMAP': [200, 200, 200],
    'BRCA': [1000, 1000, 503]
}

fig, ax = plt.subplots(figsize=(10, 6))

for i, omic in enumerate(omics):
    values = [training_features[ds][i] for ds in datasets]
    bars = ax.bar(x + i * width - width, values, width, label=omic)
    for bar in bars:
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 30, str(bar.get_height()), ha='center', va='bottom')

ax.set_title('Number of Training Features by Omics Type')
ax.set_ylabel('Training Features')
ax.set_xticks(x)
ax.set_xticklabels(datasets)
ax.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the categories and counts
datasets = ['ROSMAP', 'BRCA']

# Class labels and values
rosmap_labels = ['NC', 'AD']
rosmap_counts = [169, 182]

brca_labels = ['Normal-like', 'Basal-like', 'HER2-enriched', 'Luminal A', 'Luminal B']
brca_counts = [115, 131, 46, 436, 147]

# Align datasets and their class distributions
all_labels = [rosmap_labels, brca_labels]
all_counts = [rosmap_counts, brca_counts]

# Set up the plot
fig, ax = plt.subplots(figsize=(10, 6))

# X-axis positions
x = np.arange(len(datasets))
bar_bottoms = [0, 0]

# Define a color palette
colors = plt.cm.tab20.colors  # lots of distinct colors

# Plot stacked bars
for dataset_idx, (labels, counts) in enumerate(zip(all_labels, all_counts)):
    for i, (label, count) in enumerate(zip(labels, counts)):
        ax.bar(datasets[dataset_idx], count, bottom=bar_bottoms[dataset_idx], color=colors[i], label=label if dataset_idx == 0 else "")
        # Add text labels
        y_pos = bar_bottoms[dataset_idx] + count / 2
        ax.text(dataset_idx, y_pos, f'{label}\n({count})', ha='center', va='center', fontsize=9)
        bar_bottoms[dataset_idx] += count

# Formatting
ax.set_ylabel('Number of Samples')
ax.set_title('Stacked Bar Chart: Category Distribution in ROSMAP and BRCA')
#ax.legend(title='Classes', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Data setup
data = {
    'mRNA': [200, 1000],
    'meth': [200, 1000],
    'miRNA': [200, 503]
}
datasets = ['ROSMAP', 'BRCA']

# Create DataFrame for heatmap
df = pd.DataFrame(data, index=datasets)

# Plot heatmap
plt.figure(figsize=(8, 5))
sns.heatmap(df, annot=True, fmt='d', cmap='YlGnBu', cbar_kws={'label': 'Number of Training Features'})

plt.title('Training Features per Omics Type and Dataset')
plt.ylabel('Dataset')
plt.xlabel('Omics Type')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Training features per omic per dataset
training_features = {
    'ROSMAP': [200, 200, 200],
    'BRCA': [1000, 1000, 503]
}
datasets = list(training_features.keys())
omics = ['mRNA', 'meth', 'miRNA']
colors = ['#66c2a5', '#fc8d62', '#8da0cb']

# Bar positions
x = np.arange(len(datasets))
width = 0.6

fig, ax = plt.subplots(figsize=(8, 6))

# Plotting stacked bars
bottom = [0] * len(datasets)
for i, omic in enumerate(omics):
    values = [training_features[ds][i] for ds in datasets]
    bars = ax.bar(x, values, width, bottom=bottom, label=omic, color=colors[i])

    # Add text labels to each segment
    for j, bar in enumerate(bars):
        height = bar.get_height()
        ax.text(bar.get_x() + bar.get_width()/2, bottom[j] + height / 2, str(height), ha='center', va='center', fontsize=9)
        bottom[j] += height  # Update bottom for next stack

# Axis settings
ax.set_title('Stacked Bar Chart: Training Features by Omics Type')
ax.set_ylabel('Number of Training Features')
ax.set_xticks(x)
ax.set_xticklabels(datasets)
ax.legend(title='Omics Type')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

methods = ['Cosine Similarity', 'Cosine Distance', 'RBF Similarity', 'RBF Distance', 'Hybrid Distance', 'Hybrid Similarity']
acc = [0.877, 0.821, 0.849, 0.858, 0.830, 0.849]
f1 = [0.876, 0.819, 0.846, 0.860, 0.820, 0.846]
auc = [0.902, 0.869, 0.892, 0.871, 0.886, 0.881]

x = np.arange(len(methods))
width = 0.25

fig, ax = plt.subplots(figsize=(10, 6))

# Bars
bars1 = ax.bar(x - width, acc, width, label='Accuracy')
bars2 = ax.bar(x, f1, width, label='F1 Score')
bars3 = ax.bar(x + width, auc, width, label='AUC')

# Add text labels
for bars in [bars1, bars2, bars3]:
    for bar in bars:
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
                f'{bar.get_height():.3f}', ha='center', va='bottom', fontsize=8)

# Formatting
ax.set_ylabel('Score')
ax.set_title('Performance Comparison of ML Methods')
ax.set_xticks(x)
ax.set_xticklabels(methods)
ax.set_ylim(0, 1.1)
ax.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

methods = ['Cosine Similarity', 'Cosine Distance', 'RBF Similarity', 'RBF Distance', 'Hybrid Distance', 'Hybrid Similarity']
acc = [0.877, 0.821, 0.849, 0.858, 0.830, 0.849]
f1 = [0.876, 0.819, 0.846, 0.860, 0.820, 0.846]
auc = [0.902, 0.869, 0.892, 0.871, 0.886, 0.881]

y = np.arange(len(methods))
height = 0.20  # Height of the bars

fig, ax = plt.subplots(figsize=(11, 6))

bars1 = ax.barh(y - height, acc, height, label='Accuracy')
bars2 = ax.barh(y, f1, height, label='F1 Score')
bars3 = ax.barh(y + height, auc, height, label='AUC')

# Add text labels
for bars in [bars1, bars2, bars3]:
    for bar in bars:
        ax.text(bar.get_width() + 0.01, bar.get_y() + bar.get_height()/2,
                f'{bar.get_width():.3f}', va='center', fontsize=8)

ax.set_xlabel('Score')
ax.set_title('Performance Comparison of ML Methods (ROSMAP)')
ax.set_yticks(y)
ax.set_yticklabels(methods)
ax.set_xlim(0, 1.1)
ax.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

methods = ['Cosine Similarity', 'Cosine Distance', 'RBF Similarity', 'RBF Distance', 'Hybrid Distance', 'Hybrid Similarity']
acc = [0.877, 0.821, 0.849, 0.858, 0.830, 0.849]
f1 = [0.876, 0.819, 0.846, 0.860, 0.820, 0.846]
auc = [0.902, 0.869, 0.892, 0.871, 0.886, 0.881]

x = np.arange(len(methods))

plt.figure(figsize=(12, 6))
plt.plot(x, acc, marker='o', label='Accuracy')
plt.plot(x, f1, marker='s', label='F1 Score')
plt.plot(x, auc, marker='^', label='AUC')

# Vertical offsets for labels to prevent overlap
offsets = {
    'acc': 0.015,
    'f1': 0.005,
    'auc': 0.025,
}

for i in range(len(methods)):
    plt.text(x[i], acc[i] + offsets['acc'], f'{acc[i]:.3f}', ha='center', fontsize=8, color='C0')
    plt.text(x[i], f1[i] + offsets['f1'], f'{f1[i]:.3f}', ha='center', fontsize=8, color='C1')
    plt.text(x[i], auc[i] + offsets['auc'], f'{auc[i]:.3f}', ha='center', fontsize=8, color='C2')

plt.xticks(x, methods, rotation=30, ha='right')  # rotate x labels for better spacing
plt.ylim(0.75, 1)
plt.ylabel('Score')
plt.title('Performance Comparison of ML Methods (ROSMAP)')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

methods = ['Cosine Similarity', 'Cosine Distance', 'RBF Similarity', 'RBF Distance', 'Hybrid Distance', 'Hybrid Similarity']
acc = [0.825, 0.783, 0.821, 0.764, 0.776, 0.764]
f1_weighted = [0.817, 0.772, 0.810, 0.746, 0.766, 0.753]
f1_macro = [0.766, 0.700, 0.745, 0.671, 0.693, 0.685]

x = np.arange(len(methods))

plt.figure(figsize=(12, 6))
plt.plot(x, acc, marker='o', label='Accuracy')
plt.plot(x, f1_weighted, marker='s', label='F1 Weighted')
plt.plot(x, f1_macro, marker='^', label='F1 Macro')

# Add text annotations to prevent label overlap
for i in range(len(methods)):
    plt.text(x[i], acc[i] + 0.01, f'{acc[i]:.3f}', ha='center', fontsize=8, color='C0')
    plt.text(x[i], f1_weighted[i] - 0.015, f'{f1_weighted[i]:.3f}', ha='center', fontsize=8, color='C1')
    plt.text(x[i], f1_macro[i] + 0.015, f'{f1_macro[i]:.3f}', ha='center', fontsize=8, color='C2')

plt.xticks(x, methods, rotation=30, ha='right')
plt.ylim(0.65, 0.85)
plt.ylabel('Score')
plt.title('Performance Comparison of ML Methods (BRCA)')
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

methods =       ['Cosine Similarity', 'Cosine Distance', 'RBF Similarity', 'RBF Distance', 'Hybrid Distance', 'Hybrid Similarity']
acc =           [0.825, 0.783, 0.821, 0.764, 0.776, 0.764]
f1_weighted =   [0.817, 0.772, 0.810, 0.746, 0.766, 0.753]
f1_macro =      [0.766, 0.700, 0.745, 0.671, 0.693, 0.685]

y = np.arange(len(methods))
height = 0.20  # Height of the bars

fig, ax = plt.subplots(figsize=(11, 6))

bars1 = ax.barh(y - height, acc, height, label='Accuracy')
bars2 = ax.barh(y, f1_weighted, height, label='F1 Weighted')
bars3 = ax.barh(y + height, f1_macro, height, label='F1 Macro')

# Add text labels
for bars in [bars1, bars2, bars3]:
    for bar in bars:
        ax.text(bar.get_width() + 0.01, bar.get_y() + bar.get_height()/2,
                f'{bar.get_width():.3f}', va='center', fontsize=8)

ax.set_xlabel('Score')
ax.set_title('Performance Comparison of ML Methods (BRCA)')
ax.set_yticks(y)
ax.set_yticklabels(methods)
ax.set_xlim(0, 1.0)
ax.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the datasets
datasets = ['ROSMAP', 'BRCA']

# Class labels and values
rosmap_labels = ['NC', 'AD']
rosmap_counts = [169, 182]

brca_labels = ['Normal-like', 'Basal-like', 'HER2-enriched', 'Luminal A', 'Luminal B']
brca_counts = [115, 131, 46, 436, 147]

# Group labels and counts
all_labels = [rosmap_labels, brca_labels]
all_counts = [rosmap_counts, brca_counts]

# Set up the plot
fig, ax = plt.subplots(figsize=(10, 6))

# X-axis positions
x = np.arange(len(datasets))
bar_bottoms = [0, 0]

# Define a color palette
colors = plt.cm.tab20.colors

# Plot stacked bars with labels
for dataset_idx, (labels, counts) in enumerate(zip(all_labels, all_counts)):
    for i, (label, count) in enumerate(zip(labels, counts)):
        ax.bar(datasets[dataset_idx], count, bottom=bar_bottoms[dataset_idx],
               color=colors[i], label=label if dataset_idx == 0 else "")
        
        # Add value + label text
        y_pos = bar_bottoms[dataset_idx] + count / 2
        ax.text(dataset_idx, y_pos, f'{label}({count})',
                ha='center', va='center', fontsize=18)
        
        bar_bottoms[dataset_idx] += count

# Axis labels and title
ax.set_ylabel('Number of Samples', fontsize=14,weight='bold')
ax.set_title('Stacked Bar Chart: Category Distribution in ROSMAP and BRCA',weight='bold')
ax.set_xticks(x)
ax.set_xticklabels(datasets, fontsize=15)
ax.tick_params(axis='y', labelsize=15)

# Optional legend (uncomment if needed)
# ax.legend(title='Classes', fontsize=11, title_fontsize=12, bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.savefig("stacked_bar_brca_rosmap.png", dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Data
total_features = {
    'ROSMAP': [55889, 23788, 309],
    'BRCA': [20531, 20106, 503]
}
omics = ['mRNA', 'meth', 'miRNA']

# Create DataFrame
df = pd.DataFrame(total_features, index=omics).T

# Plot
plt.figure(figsize=(8, 5))
sns.set(font_scale=1.2)  # globally scale font sizes
heatmap = sns.heatmap(
    df,
    annot=True,
    fmt=',d',  # comma for thousands
    cmap='BuPu',
    linewidths=0.5,
    cbar_kws={'label': 'Number of Features'},
    annot_kws={"size": 13, "weight": 'bold'}
)

# Titles and labels
plt.title('Total Number of Features by Omics Type', fontsize=16, weight='bold', pad=15)
plt.xlabel('Omics Type', fontsize=14, weight='bold', labelpad=10)
plt.ylabel('Dataset', fontsize=14, weight='bold', labelpad=10)

# Tick font sizes
heatmap.set_xticklabels(heatmap.get_xticklabels(), fontsize=12)
heatmap.set_yticklabels(heatmap.get_yticklabels(), fontsize=12, rotation=0)

plt.tight_layout()
plt.savefig("heatmap_total_features.png", dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Data setup
data = {
    'mRNA': [200, 1000],
    'meth': [200, 1000],
    'miRNA': [200, 503]
}
datasets = ['ROSMAP', 'BRCA']

# Create DataFrame
df = pd.DataFrame(data, index=datasets)

# Plot heatmap
plt.figure(figsize=(8, 5))
sns.set(font_scale=1.2)  # Scale font globally

heatmap = sns.heatmap(
    df,
    annot=True,
    fmt='d',
    cmap='YlGnBu',
    linewidths=0.5,
    linecolor='gray',
    annot_kws={"size": 13, "weight": 'bold'},
    cbar_kws={'label': 'Number of Training Features'}
)

# Labels and titles
plt.title('Training Features per Omics Type and Dataset', fontsize=16, weight='bold', pad=15)
plt.xlabel('Omics Type', fontsize=14, weight='bold', labelpad=10)
plt.ylabel('Dataset', fontsize=14, weight='bold', labelpad=10)

# Tick font size and rotation
heatmap.set_xticklabels(heatmap.get_xticklabels(), fontsize=12)
heatmap.set_yticklabels(heatmap.get_yticklabels(), fontsize=12, rotation=0)

plt.tight_layout()
plt.savefig("training_features_heatmap.png", dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Categories and dataset splits
categories = ['ROSMAP', 'BRCA']
training_counts = [245, 612]
testing_counts = [106, 263]

x = np.arange(len(categories))
bar_width = 0.8  # Reduced width for smaller gap

# Colors: training = steelblue, testing = darkorange
train_color = '#4682B4'
test_color = '#FFA07A'

# Plotting
fig, ax = plt.subplots(figsize=(8, 6))

# Stacked bars
train_bars = ax.bar(x, training_counts, bar_width, label='Training', color=train_color)
test_bars = ax.bar(x, testing_counts, bar_width, bottom=training_counts, label='Testing', color=test_color)

# Add value labels
for i in range(len(categories)):
    ax.text(x[i], training_counts[i]/2, f'{training_counts[i]}',
            ha='center', va='center', color='white', fontsize=12, weight='bold')
    ax.text(x[i], training_counts[i] + testing_counts[i]/2, f'{testing_counts[i]}',
            ha='center', va='center', color='black', fontsize=12, weight='bold')

# Labels and formatting
ax.set_ylabel('Number of Samples', fontsize=14, weight='bold')
ax.set_title('Dataset Split by Category', fontsize=16, weight='bold')
ax.set_xticks(x)
ax.set_xticklabels(categories, fontsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.legend(fontsize=12)

# Clean layout
plt.tight_layout()
plt.savefig("stacked_split_bars.png", dpi=300)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import pi
import matplotlib.ticker as ticker

# Original data
data = [
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.877, "F1": 0.876, "AUC": 0.902},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.821, "F1": 0.819, "AUC": 0.863},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.892},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.858, "F1": 0.860, "AUC": 0.871},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.881},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.830, "F1": 0.820, "AUC": 0.886},
]

df = pd.DataFrame(data)

# Radar chart setup
metrics = ['Accuracy', 'F1', 'AUC']
num_vars = len(metrics)
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
angles += angles[:1]  # close the loop

# Create figure
fig, ax = plt.subplots(figsize=(9, 9), subplot_kw=dict(polar=True))

# Plot each method
for _, row in df.iterrows():
    values = row[metrics].tolist()
    values += values[:1]
    ax.plot(angles, values, label=row["Method"], linewidth=2)
    ax.fill(angles, values, alpha=0.1)

# Axis configuration
ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)
ax.set_thetagrids(np.degrees(angles[:-1]), metrics, fontsize=14, weight='bold')

# Radial ticks
custom_ticks = np.arange(0.7, .95, 0.1)
ax.set_ylim(0.7, 0.95)
ax.set_yticks(custom_ticks)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f"{x:.2f}"))
ax.tick_params(axis='y', labelsize=19)
ax.set_rlabel_position(180 / num_vars)

# Title and legend
plt.title("ROSMAP", fontsize=18, weight='bold', pad=20)
plt.legend(loc='upper right', bbox_to_anchor=(1.3, 1.0), fontsize=11)
plt.tight_layout()
#plt.savefig("rosmap_radar_chart.png", dpi=300)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import pi
import matplotlib.ticker as ticker

# Original data
data = [
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.877, "F1": 0.876, "AUC": 0.902},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.821, "F1": 0.819, "AUC": 0.863},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.892},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.858, "F1": 0.860, "AUC": 0.871},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.881},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.830, "F1": 0.820, "AUC": 0.886},
]

df = pd.DataFrame(data)

# Radar chart setup
metrics = ['Accuracy', 'F1', 'AUC']
num_vars = len(metrics)
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
angles += angles[:1]  # close the circle

fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

# Plot each method
for _, row in df.iterrows():
    values = row[metrics].tolist()
    values += values[:1]
    ax.plot(angles, values, label=row["Method"])
    ax.fill(angles, values, alpha=0.1)

# Set up axis
ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)
ax.set_thetagrids(np.degrees(angles[:-1]), metrics)

# Custom radial ticks from 0.7 to 1.0
custom_ticks = np.arange(0.6, 1.01, 0.1)
ax.set_ylim(0.7, 1.0)
ax.set_yticks(custom_ticks)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f"{x:.2f}"))
ax.set_rlabel_position(180 / num_vars)

plt.title("ROSMAP")
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1.0))
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Prepare the heatmap data
df_heatmap = df.set_index("Method")[["Accuracy", "F1", "AUC"]]

# Plot
plt.figure(figsize=(9, 6))
sns.set(font_scale=1.2)  # Globally increase font scale

heatmap = sns.heatmap(
    df_heatmap,
    annot=True,
    fmt=".3f",
    cmap="YlGnBu",
    linewidths=0.5,
    annot_kws={"size": 18, "weight": "bold"}
)

# Titles and labels
plt.title("ROSMAP Performance Metrics by Method", fontsize=16, weight='bold', pad=15)
plt.xlabel("Metrics", fontsize=14, weight='bold', labelpad=10)
plt.ylabel("Similarity Methods", fontsize=14, weight='bold', labelpad=10)

# Axis tick label size
heatmap.set_xticklabels(heatmap.get_xticklabels(), fontsize=12)
heatmap.set_yticklabels(heatmap.get_yticklabels(), fontsize=12, rotation=0)

plt.tight_layout()
#plt.savefig("rosmap_method_heatmap.png", dpi=300)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define BRCA (data1) and ROSMAP (data2)
data1 = [ 
    {"Dataset": "BRCA", "Method": "Cosine Similarity", "Accuracy": 0.825, "F1 weighted": 0.817, "F1 macro": 0.766},
    {"Dataset": "BRCA", "Method": "Cosine Distance", "Accuracy": 0.783, "F1 weighted": 0.772, "F1 macro": 0.700},
    {"Dataset": "BRCA", "Method": "RBF Similarity", "Accuracy": 0.821, "F1 weighted": 0.810, "F1 macro": 0.745},
    {"Dataset": "BRCA", "Method": "RBF Distance", "Accuracy": 0.764, "F1 weighted": 0.764, "F1 macro": 0.671},
    {"Dataset": "BRCA", "Method": "Hybrid Similarity", "Accuracy": 0.764, "F1 weighted": 0.753, "F1 macro": 0.685},
    {"Dataset": "BRCA", "Method": "Hybrid Distance", "Accuracy": 0.776, "F1 weighted": 0.766, "F1 macro": 0.693},
]

data2 = [ 
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.877, "F1": 0.876, "AUC": 0.902},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.821, "F1": 0.819, "AUC": 0.863},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.892},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.858, "F1": 0.860, "AUC": 0.871},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.881},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.830, "F1": 0.820, "AUC": 0.886},
]

# Convert and melt
df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

df1_melted = df1.melt(id_vars="Method", value_vars=["Accuracy", "F1 weighted", "F1 macro"], 
                      var_name="Metric", value_name="Score")
df2_melted = df2.melt(id_vars="Method", value_vars=["Accuracy", "F1", "AUC"], 
                      var_name="Metric", value_name="Score")

# Plotting
sns.set(style="whitegrid", palette="Set2", font_scale=1.2)
fig, axes = plt.subplots(1, 2, figsize=(16, 6), sharey=True)

# BRCA
sns.lineplot(data=df1_melted, x="Metric", y="Score", hue="Method", marker="o", linewidth=2.5, ax=axes[0])
axes[0].set_title("BRCA: Accuracy, F1 (Weighted & Macro)", fontsize=14, weight='bold')
axes[0].set_ylabel("Score", fontsize=12)
axes[0].set_xlabel("Metric", fontsize=12)
axes[0].tick_params(axis='x', labelrotation=20)

# ROSMAP
sns.lineplot(data=df2_melted, x="Metric", y="Score", hue="Method", marker="o", linewidth=2.5, ax=axes[1])
axes[1].set_title("ROSMAP: Accuracy, F1, AUC", fontsize=14, weight='bold')
axes[1].set_ylabel("")  # shared y-axis
axes[1].set_xlabel("Metric", fontsize=12)
axes[1].tick_params(axis='x', labelrotation=20)

# Main title
plt.suptitle("Comparison of Classification Metrics: BRCA vs ROSMAP", fontsize=16, weight='bold', y=1.02)
plt.tight_layout()
plt.subplots_adjust(top=0.88)
#plt.savefig("brca_vs_rosmap_metrics.png", dpi=300)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Data
data = [
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.877, "F1": 0.876, "AUC": 0.902},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.821, "F1": 0.819, "AUC": 0.863},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.892},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.858, "F1": 0.860, "AUC": 0.871},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.881},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.830, "F1": 0.820, "AUC": 0.886},
]

df = pd.DataFrame(data)

# Melt into long format
df_melt = df.melt(id_vars=["Method"], value_vars=["Accuracy", "F1", "AUC"],
                  var_name="Metric", value_name="Value")

# Plot
plt.figure(figsize=(9, 6))
sns.set(style="whitegrid", font_scale=1.2)

sns.violinplot(
    data=df_melt,
    x="Metric",
    y="Value",
    inner="point",
    linewidth=1.3,
    palette="pastel"
)

# Formatting
plt.title("ROSMAP: Distribution of Accuracy, F1, and AUC across Methods", fontsize=16, weight='bold')
plt.xlabel("Metric", fontsize=13, weight='bold')
plt.ylabel("Score", fontsize=13, weight='bold')
plt.ylim(0.6, 1.0)
plt.grid(True, linestyle='--', alpha=0.4)
plt.tight_layout()
plt.savefig("rosmap_violin_plot.png", dpi=300)
plt.show()
# Out:
# C:\Users\MBHS_PC\AppData\Local\Temp\ipykernel_9072\2626666933.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Data
data = [
    {"Dataset": "BRCA", "Method": "Cosine Similarity", "Accuracy": 0.825, "F1 weighted": 0.817, "F1 macro": 0.766},
    {"Dataset": "BRCA", "Method": "Cosine Distance", "Accuracy": 0.783, "F1 weighted": 0.772, "F1 macro": 0.700},
    {"Dataset": "BRCA", "Method": "RBF Similarity", "Accuracy": 0.821, "F1 weighted": 0.810, "F1 macro": 0.745},
    {"Dataset": "BRCA", "Method": "RBF Distance", "Accuracy": 0.764, "F1 weighted": 0.764, "F1 macro": 0.671},
    {"Dataset": "BRCA", "Method": "Hybrid Similarity", "Accuracy": 0.764, "F1 weighted": 0.753, "F1 macro": 0.685},
    {"Dataset": "BRCA", "Method": "Hybrid Distance", "Accuracy": 0.776, "F1 weighted": 0.766, "F1 macro": 0.693}
]

df = pd.DataFrame(data)

# Melt into long format
df_melt = df.melt(id_vars=["Method"], value_vars=["Accuracy", "F1 weighted", "F1 macro"],
                  var_name="Metric", value_name="Value")

# Plot
plt.figure(figsize=(9, 6))
sns.set(style="whitegrid", font_scale=1.2)

sns.violinplot(
    data=df_melt,
    x="Metric",
    y="Value",
    inner="point",
    linewidth=1.3,
    palette="pastel"
)

# Formatting
plt.title("BRCA: Distribution of Accuracy, F1 weighted, and F1 macro across Methods", fontsize=16, weight='bold')
plt.xlabel("Metric", fontsize=13, weight='bold')
plt.ylabel("Score", fontsize=13, weight='bold')
plt.ylim(0.6, 1.0)
plt.grid(True, linestyle='--', alpha=0.4)
plt.tight_layout()
#plt.savefig("rosmap_violin_plot.png", dpi=300)
plt.show()
# Out:
# C:\Users\MBHS_PC\AppData\Local\Temp\ipykernel_23532\844211823.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Prepare the heatmap data
df_heatmap = df.set_index("Method")[["Accuracy", "F1 weighted", "F1 macro"]]

# Plot
plt.figure(figsize=(9, 6))
sns.set(font_scale=1.2)  # Globally increase font scale

heatmap = sns.heatmap(
    df_heatmap,
    annot=True,
    fmt=".3f",
    cmap="YlGnBu",
    linewidths=0.5,
    annot_kws={"size": 18, "weight": "bold"}
)

# Titles and labels
plt.title("BRCA Performance Metrics by Method", fontsize=16, weight='bold', pad=15)
plt.xlabel("Metrics", fontsize=14, weight='bold', labelpad=10)
plt.ylabel("Similarity Methods", fontsize=14, weight='bold', labelpad=10)

# Axis tick label size
heatmap.set_xticklabels(heatmap.get_xticklabels(), fontsize=12)
heatmap.set_yticklabels(heatmap.get_yticklabels(), fontsize=12, rotation=0)

plt.tight_layout()
#plt.savefig("rosmap_method_heatmap.png", dpi=300)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import pi
import matplotlib.ticker as ticker

# Original data
data = [
    {"Dataset": "BRCA", "Method": "Cosine Similarity", "Accuracy": 0.825, "F1 weighted": 0.817, "F1 macro": 0.766},
    {"Dataset": "BRCA", "Method": "Cosine Distance", "Accuracy": 0.783, "F1 weighted": 0.772, "F1 macro": 0.700},
    {"Dataset": "BRCA", "Method": "RBF Similarity", "Accuracy": 0.821, "F1 weighted": 0.810, "F1 macro": 0.745},
    {"Dataset": "BRCA", "Method": "RBF Distance", "Accuracy": 0.764, "F1 weighted": 0.764, "F1 macro": 0.671},
    {"Dataset": "BRCA", "Method": "Hybrid Similarity", "Accuracy": 0.764, "F1 weighted": 0.753, "F1 macro": 0.685},
    {"Dataset": "BRCA", "Method": "Hybrid Distance", "Accuracy": 0.776, "F1 weighted": 0.766, "F1 macro": 0.693}
]

df = pd.DataFrame(data)

# Radar chart setup
metrics = ['Accuracy', 'F1 weighted', 'F1 macro']
num_vars = len(metrics)
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
angles += angles[:1]  # close the loop

# Create figure
fig, ax = plt.subplots(figsize=(9, 9), subplot_kw=dict(polar=True))

# Plot each method
for _, row in df.iterrows():
    values = row[metrics].tolist()
    values += values[:1]
    ax.plot(angles, values, label=row["Method"], linewidth=2)
    ax.fill(angles, values, alpha=0.1)

# Axis configuration
ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)
ax.set_thetagrids(np.degrees(angles[:-1]), metrics, fontsize=14, weight='bold')

# Radial ticks
custom_ticks = np.arange(0.6, .85, 0.1)
ax.set_ylim(0.6, 0.85)
ax.set_yticks(custom_ticks)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f"{x:.2f}"))
ax.tick_params(axis='y', labelsize=19)
ax.set_rlabel_position(180 / num_vars)

# Title and legend
plt.title("BRCA", fontsize=18, weight='bold', pad=20)
plt.legend(loc='upper right', bbox_to_anchor=(1.3, 1.0), fontsize=11)
plt.tight_layout()
#plt.savefig("rosmap_radar_chart.png", dpi=300)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Data in long format
data = [
    # ROSMAP
    {"Similarity": "Cosine-sim", "Dataset": "ROSMAP", "Metric": "Accuracy", "Score": 0.877},
    {"Similarity": "Cosine-sim", "Dataset": "ROSMAP", "Metric": "F1-score", "Score": 0.876},
    {"Similarity": "Cosine-sim", "Dataset": "ROSMAP", "Metric": "AUC", "Score": 0.902},

    {"Similarity": "Cosine-dist", "Dataset": "ROSMAP", "Metric": "Accuracy", "Score": 0.821},
    {"Similarity": "Cosine-dist", "Dataset": "ROSMAP", "Metric": "F1-score", "Score": 0.819},
    {"Similarity": "Cosine-dist", "Dataset": "ROSMAP", "Metric": "AUC", "Score": 0.869},

    {"Similarity": "RBF-sim", "Dataset": "ROSMAP", "Metric": "Accuracy", "Score": 0.849},
    {"Similarity": "RBF-sim", "Dataset": "ROSMAP", "Metric": "F1-score", "Score": 0.846},
    {"Similarity": "RBF-sim", "Dataset": "ROSMAP", "Metric": "AUC", "Score": 0.892},

    {"Similarity": "RBF-dist", "Dataset": "ROSMAP", "Metric": "Accuracy", "Score": 0.858},
    {"Similarity": "RBF-dist", "Dataset": "ROSMAP", "Metric": "F1-score", "Score": 0.860},
    {"Similarity": "RBF-dist", "Dataset": "ROSMAP", "Metric": "AUC", "Score": 0.871},

    {"Similarity": "Hybrid-sim", "Dataset": "ROSMAP", "Metric": "Accuracy", "Score": 0.849},
    {"Similarity": "Hybrid-sim", "Dataset": "ROSMAP", "Metric": "F1-score", "Score": 0.846},
    {"Similarity": "Hybrid-sim", "Dataset": "ROSMAP", "Metric": "AUC", "Score": 0.881},

    {"Similarity": "Hybrid-dist", "Dataset": "ROSMAP", "Metric": "Accuracy", "Score": 0.830},
    {"Similarity": "Hybrid-dist", "Dataset": "ROSMAP", "Metric": "F1-score", "Score": 0.820},
    {"Similarity": "Hybrid-dist", "Dataset": "ROSMAP", "Metric": "AUC", "Score": 0.886},

    # BRCA
    {"Similarity": "Cosine-sim", "Dataset": "BRCA", "Metric": "Accuracy", "Score": 0.825},
    {"Similarity": "Cosine-sim", "Dataset": "BRCA", "Metric": "F1-score", "Score": 0.817},
    {"Similarity": "Cosine-sim", "Dataset": "BRCA", "Metric": "AUC", "Score": 0.766},

    {"Similarity": "Cosine-dist", "Dataset": "BRCA", "Metric": "Accuracy", "Score": 0.783},
    {"Similarity": "Cosine-dist", "Dataset": "BRCA", "Metric": "F1-score", "Score": 0.772},
    {"Similarity": "Cosine-dist", "Dataset": "BRCA", "Metric": "AUC", "Score": 0.700},

    {"Similarity": "RBF-sim", "Dataset": "BRCA", "Metric": "Accuracy", "Score": 0.821},
    {"Similarity": "RBF-sim", "Dataset": "BRCA", "Metric": "F1-score", "Score": 0.810},
    {"Similarity": "RBF-sim", "Dataset": "BRCA", "Metric": "AUC", "Score": 0.745},

    {"Similarity": "RBF-dist", "Dataset": "BRCA", "Metric": "Accuracy", "Score": 0.764},
    {"Similarity": "RBF-dist", "Dataset": "BRCA", "Metric": "F1-score", "Score": 0.746},
    {"Similarity": "RBF-dist", "Dataset": "BRCA", "Metric": "AUC", "Score": 0.671},

    {"Similarity": "Hybrid-sim", "Dataset": "BRCA", "Metric": "Accuracy", "Score": 0.764},
    {"Similarity": "Hybrid-sim", "Dataset": "BRCA", "Metric": "F1-score", "Score": 0.753},
    {"Similarity": "Hybrid-sim", "Dataset": "BRCA", "Metric": "AUC", "Score": 0.685},

    {"Similarity": "Hybrid-dist", "Dataset": "BRCA", "Metric": "Accuracy", "Score": 0.776},
    {"Similarity": "Hybrid-dist", "Dataset": "BRCA", "Metric": "F1-score", "Score": 0.766},
    {"Similarity": "Hybrid-dist", "Dataset": "BRCA", "Metric": "AUC", "Score": 0.693},
]

df = pd.DataFrame(data)

# Plot
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")

ax = sns.barplot(
    data=df,
    x="Similarity",
    y="Score",
    hue="Dataset",
    ci=None,
    palette="muted",
    dodge=True
)

# Add labels
ax.set_title("Performance Comparison Across Similarity Metrics")
ax.set_ylabel("Score (Accuracy / F1 / AUC)")
ax.set_xlabel("Similarity Metric")
ax.set_ylim(0.65, 0.95)
plt.xticks(rotation=45)
plt.legend(title="Dataset")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MBHS_PC\AppData\Local\Temp\ipykernel_17292\637801351.py:64: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from math import pi

# --- Data ---
data_brca = [ 
    {"Dataset": "BRCA", "Method": "Cosine Similarity", "Accuracy": 0.825, "F1": 0.817, "F1 macro": 0.766},
    {"Dataset": "BRCA", "Method": "Cosine Distance", "Accuracy": 0.783, "F1": 0.772, "F1 macro": 0.700},
    {"Dataset": "BRCA", "Method": "RBF Similarity", "Accuracy": 0.821, "F1": 0.810, "F1 macro": 0.745},
    {"Dataset": "BRCA", "Method": "RBF Distance", "Accuracy": 0.764, "F1": 0.764, "F1 macro": 0.671},
    {"Dataset": "BRCA", "Method": "Hybrid Similarity", "Accuracy": 0.764, "F1": 0.753, "F1 macro": 0.685},
    {"Dataset": "BRCA", "Method": "Hybrid Distance", "Accuracy": 0.776, "F1": 0.766, "F1 macro": 0.693}
]

data_rosmap = [ 
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.877, "F1": 0.876, "AUC": 0.902},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.821, "F1": 0.819, "AUC": 0.863},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.892},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.858, "F1": 0.860, "AUC": 0.871},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.881},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.830, "F1": 0.820, "AUC": 0.886}
]

df_brca = pd.DataFrame(data_brca)
df_rosmap = pd.DataFrame(data_rosmap)

# Merge both datasets
df_brca["F1 macro"] = df_brca["F1 macro"]
df_rosmap["F1 macro"] = df_rosmap["F1"]  # rename for consistency

df_all = pd.concat([df_brca, df_rosmap], ignore_index=True)

# --- Plotting ---
sns.set(style="whitegrid", font_scale=1.1)
fig, axs = plt.subplots(1, 3, figsize=(20, 6))

# ---------- PANEL A: Grouped Accuracy Bar Chart ----------
sns.barplot(data=df_all, x="Method", y="Accuracy", hue="Dataset", ax=axs[0], palette="Set2")
axs[0].set_title("A. Accuracy Comparison", fontsize=14, weight='bold')
axs[0].set_xticklabels(axs[0].get_xticklabels(), rotation=20)
axs[0].set_ylabel("Accuracy")
axs[0].legend(title="Dataset")

# ---------- PANEL B: Line Chart of F1 Score ----------
f1_data = df_all.melt(id_vars=["Dataset", "Method"], value_vars=["F1", "F1 macro"], 
                      var_name="Metric", value_name="Score")
sns.lineplot(data=f1_data, x="Metric", y="Score", hue="Method", style="Dataset",
             markers=True, dashes=False, ax=axs[1])
axs[1].set_title("B. F1 Score Comparison", fontsize=14, weight='bold')
axs[1].set_ylabel("F1 Score")

ax = axs[2]
ax = plt.subplot(133, polar=True)
for idx, method in enumerate(radar_methods):
    rosmap_vals = df_rosmap[df_rosmap["Method"] == method][['Accuracy', 'F1', 'AUC']].values.flatten().tolist()
    rosmap_vals += rosmap_vals[:1]
    ax.plot(angles, rosmap_vals, label=method, linewidth=2, alpha=0.8)
    ax.fill(angles, rosmap_vals, alpha=0.05)

ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)
ax.set_thetagrids(np.degrees(angles[:-1]), categories)
ax.set_ylim(0.7, 1.0)
ax.legend(loc='upper right', bbox_to_anchor=(1.5, 1.0), fontsize=8)

# ---------- Final Layout ----------
plt.suptitle("Combined Evaluation of Similarity Methods on BRCA and ROSMAP", fontsize=16, weight='bold', y=1.05)
plt.tight_layout()
plt.subplots_adjust(top=0.85)
plt.savefig("combined_similarity_comparison.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\MBHS_PC\AppData\Local\Temp\ipykernel_17292\278867987.py:42: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[0].set_xticklabels(axs[0].get_xticklabels(), rotation=20)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# ----------------- Data -----------------
brca = pd.DataFrame(data_brca)
rosmap = pd.DataFrame(data_rosmap)

brca['Delta'] = brca['Accuracy'].diff().fillna(0)
rosmap['Delta'] = rosmap['Accuracy'].diff().fillna(0)

# ----------------- Plot Setup -----------------
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

colors_brca = ['green' if val >= 0 else 'red' for val in brca['Delta']]
colors_rosmap = ['green' if val >= 0 else 'red' for val in rosmap['Delta']]

# ----------------- BRCA Waterfall -----------------
axes[0].bar(brca['Method'], brca['Delta'], bottom=brca['Accuracy'].cumsum() - brca['Delta'], color=colors_brca)
axes[0].plot(brca['Method'], brca['Accuracy'].cumsum(), marker='o', color='black')
axes[0].set_title("BRCA - Accuracy Waterfall", fontsize=14, weight='bold')
axes[0].set_ylabel("Accuracy")
axes[0].set_xticklabels(brca['Method'], rotation=20)
axes[0].grid(True, axis='y', linestyle='--', alpha=0.5)

# ----------------- ROSMAP Waterfall -----------------
axes[1].bar(rosmap['Method'], rosmap['Delta'], bottom=rosmap['Accuracy'].cumsum() - rosmap['Delta'], color=colors_rosmap)
axes[1].plot(rosmap['Method'], rosmap['Accuracy'].cumsum(), marker='o', color='black')
axes[1].set_title("ROSMAP - Accuracy Waterfall", fontsize=14, weight='bold')
axes[1].set_ylabel("Accuracy")
axes[1].set_xticklabels(rosmap['Method'], rotation=20)
axes[1].grid(True, axis='y', linestyle='--', alpha=0.5)

# ----------------- Final Layout -----------------
plt.suptitle("Waterfall Chart of Accuracy across Similarity Methods", fontsize=16, weight='bold')
plt.tight_layout()
plt.subplots_adjust(top=0.88)
plt.savefig("waterfall_accuracy_brca_rosmap.png", dpi=300)
plt.show()
# Out:
# C:\Users\MBHS_PC\AppData\Local\Temp\ipykernel_17292\1577366191.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels(brca['Method'], rotation=20)
# C:\Users\MBHS_PC\AppData\Local\Temp\ipykernel_17292\1577366191.py:30: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(rosmap['Method'], rotation=20)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# --- Combined Data ---
data_brca = [ 
    {"Dataset": "BRCA", "Method": "Cosine Similarity", "Accuracy": 0.825, "F1": 0.817},
    {"Dataset": "BRCA", "Method": "Cosine Distance", "Accuracy": 0.783, "F1": 0.772},
    {"Dataset": "BRCA", "Method": "RBF Similarity", "Accuracy": 0.821, "F1": 0.810},
    {"Dataset": "BRCA", "Method": "RBF Distance", "Accuracy": 0.764, "F1": 0.764},
    {"Dataset": "BRCA", "Method": "Hybrid Similarity", "Accuracy": 0.764, "F1": 0.753},
    {"Dataset": "BRCA", "Method": "Hybrid Distance", "Accuracy": 0.776, "F1": 0.766}
]

data_rosmap = [ 
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.877, "F1": 0.876, "AUC": 0.902},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.821, "F1": 0.819, "AUC": 0.863},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.892},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.858, "F1": 0.860, "AUC": 0.871},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.881},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.830, "F1": 0.820, "AUC": 0.886}
]

# Convert to DataFrame and melt
df_brca = pd.DataFrame(data_brca).melt(id_vars=["Dataset", "Method"], var_name="Metric", value_name="Score")
df_rosmap = pd.DataFrame(data_rosmap).melt(id_vars=["Dataset", "Method"], var_name="Metric", value_name="Score")
df_all = pd.concat([df_brca, df_rosmap])

# Remove AUC for BRCA
df_all = df_all[~((df_all["Dataset"] == "BRCA") & (df_all["Metric"] == "AUC"))]

# --- Plot ---
sns.set(style="whitegrid", font_scale=1.2)
g = sns.catplot(
    data=df_all,
    kind="bar",
    x="Method",
    y="Score",
    hue="Dataset",
    col="Metric",
    col_wrap=2,
    palette="Set2",
    height=5,
    aspect=1.3
)

g.set_titles("{col_name}")
g.set_xticklabels(rotation=20)
g.fig.subplots_adjust(top=0.85)
g.fig.suptitle("Performance Comparison of Similarity Methods (BRCA vs ROSMAP)", fontsize=16, weight='bold')

# Save
plt.savefig("brca_rosmap_grouped_bar_fixed.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# --- Dataset Setup ---
data_brca = [ 
    {"Dataset": "BRCA", "Method": "Cosine Similarity", "Accuracy": 0.825, "F1": 0.817},
    {"Dataset": "BRCA", "Method": "Cosine Distance", "Accuracy": 0.783, "F1": 0.772},
    {"Dataset": "BRCA", "Method": "RBF Similarity", "Accuracy": 0.821, "F1": 0.810},
    {"Dataset": "BRCA", "Method": "RBF Distance", "Accuracy": 0.764, "F1": 0.764},
    {"Dataset": "BRCA", "Method": "Hybrid Similarity", "Accuracy": 0.764, "F1": 0.753},
    {"Dataset": "BRCA", "Method": "Hybrid Distance", "Accuracy": 0.776, "F1": 0.766}
]

data_rosmap = [ 
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.877, "F1": 0.876, "AUC": 0.902},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.821, "F1": 0.819, "AUC": 0.863},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.892},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.858, "F1": 0.860, "AUC": 0.871},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.881},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.830, "F1": 0.820, "AUC": 0.886},
]

# --- Combine and Melt ---
df_brca = pd.DataFrame(data_brca).melt(id_vars=["Dataset", "Method"], var_name="Metric", value_name="Score")
df_rosmap = pd.DataFrame(data_rosmap).melt(id_vars=["Dataset", "Method"], var_name="Metric", value_name="Score")
df_all = pd.concat([df_brca, df_rosmap], ignore_index=True)

# Remove AUC for BRCA
df_all = df_all[~((df_all["Dataset"] == "BRCA") & (df_all["Metric"] == "AUC"))]

# --- Plot ---
sns.set(style="whitegrid", font_scale=1.2)
g = sns.catplot(
    data=df_all,
    kind="point",
    x="Method",
    y="Score",
    hue="Dataset",
    col="Metric",
    col_wrap=2,
    palette="Set2",
    dodge=True,
    height=5,
    aspect=1.4,
    markers=["o", "s"],
    linestyles=["-", "--"]
)

# --- Customizations ---
g.set_titles("{col_name}", size=14, weight='bold')
g.set_xticklabels(rotation=20)
g.fig.subplots_adjust(top=0.85)
g.fig.suptitle("Point Plot Comparison of Similarity Methods on BRCA and ROSMAP", fontsize=16, weight='bold')

# Save high-quality image
g.savefig("pointplot_brca_rosmap.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# ---------- DATA ----------
data_brca = [ 
    {"Dataset": "BRCA", "Method": "Cosine Similarity", "Accuracy": 0.825, "F1": 0.817},
    {"Dataset": "BRCA", "Method": "Cosine Distance", "Accuracy": 0.783, "F1": 0.772},
    {"Dataset": "BRCA", "Method": "RBF Similarity", "Accuracy": 0.821, "F1": 0.810},
    {"Dataset": "BRCA", "Method": "RBF Distance", "Accuracy": 0.764, "F1": 0.764},
    {"Dataset": "BRCA", "Method": "Hybrid Similarity", "Accuracy": 0.764, "F1": 0.753},
    {"Dataset": "BRCA", "Method": "Hybrid Distance", "Accuracy": 0.776, "F1": 0.766}
]

data_rosmap = [ 
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.877, "F1": 0.876, "AUC": 0.902},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.821, "F1": 0.819, "AUC": 0.863},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.892},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.858, "F1": 0.860, "AUC": 0.871},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.881},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.830, "F1": 0.820, "AUC": 0.886},
]

# ---------- PREPARE DATA ----------
# Convert both datasets into DataFrames and melt them to long-form
df_brca = pd.DataFrame(data_brca).melt(id_vars=["Dataset", "Method"], var_name="Metric", value_name="Score")
df_rosmap = pd.DataFrame(data_rosmap).melt(id_vars=["Dataset", "Method"], var_name="Metric", value_name="Score")

# Combine datasets
df = pd.concat([df_brca, df_rosmap], ignore_index=True)

# ---------- PLOT ----------
sns.set(style="whitegrid", font_scale=1.2)
g = sns.catplot(
    data=df,
    x="Method",
    y="Score",
    hue="Metric",
    col="Dataset",
    kind="point",
    dodge=True,
    markers=["o", "s", "D"],
    linestyles=["-", "--", ":"],
    palette="Set2",
    height=6,
    aspect=1.5
)

# Format
g.set_xticklabels(rotation=20)
g.set_titles("{col_name}", size=14, weight='bold')
g.fig.subplots_adjust(top=0.85)
g.fig.suptitle("Comparison of Similarity Methods across Datasets", fontsize=16, weight='bold')

# Save high-res image for publication
g.savefig("point_plot_similarity_comparison.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# -------- DEFINE YOUR DATA HERE --------
data_brca = [ 
    {"Dataset": "BRCA", "Method": "Cosine Similarity", "Accuracy": 0.825, "F1 weighted": 0.817, "F1 macro": 0.766},
    {"Dataset": "BRCA", "Method": "Cosine Distance", "Accuracy": 0.783, "F1 weighted": 0.772, "F1 macro": 0.700},
    {"Dataset": "BRCA", "Method": "RBF Similarity", "Accuracy": 0.821, "F1 weighted": 0.810, "F1 macro": 0.745},
    {"Dataset": "BRCA", "Method": "RBF Distance", "Accuracy": 0.764, "F1 weighted": 0.764, "F1 macro": 0.671},
    {"Dataset": "BRCA", "Method": "Hybrid Similarity", "Accuracy": 0.764, "F1 weighted": 0.753, "F1 macro": 0.685},
    {"Dataset": "BRCA", "Method": "Hybrid Distance", "Accuracy": 0.776, "F1 weighted": 0.766, "F1 macro": 0.693},
]

data_rosmap = [ 
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.877, "F1": 0.876, "AUC": 0.902},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.821, "F1": 0.819, "AUC": 0.863},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.892},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.858, "F1": 0.860, "AUC": 0.871},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.881},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.830, "F1": 0.820, "AUC": 0.886},
]

# -------- PREPROCESSING --------
# Rename F1 weighted to F1 for consistent naming
df_brca = pd.DataFrame(data_brca).rename(columns={"F1 weighted": "F1"})
df_rosmap = pd.DataFrame(data_rosmap)

# Combine both
df_all = pd.concat([df_brca, df_rosmap], ignore_index=True)

# -------- PLOT --------
sns.set(style="whitegrid", font_scale=1.2)
metrics = ['Accuracy', 'F1', 'AUC']

# Set up subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=False)

for idx, metric in enumerate(metrics):
    ax = axes[idx]
    plot_data = df_all.dropna(subset=[metric])
    sns.barplot(data=plot_data, x='Method', y=metric, hue='Dataset', ax=ax, palette='Set2')
    ax.set_title(f'{metric} Comparison by Method', fontsize=14, weight='bold')
    ax.set_xlabel('Similarity Method')
    ax.set_ylabel(metric)
    ax.tick_params(axis='x', rotation=20)
    ax.legend(title='Dataset')

plt.suptitle('Cross-Dataset Performance Comparison of Similarity Networks', fontsize=16, weight='bold')
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.savefig("cross_dataset_barplot.png", dpi=300)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Raw data
data_brca = [ 
    {"Dataset": "BRCA", "Method": "Cosine Similarity", "Accuracy": 0.825, "F1 weighted": 0.817, "F1 macro": 0.766},
    {"Dataset": "BRCA", "Method": "Cosine Distance", "Accuracy": 0.783, "F1 weighted": 0.772, "F1 macro": 0.700},
    {"Dataset": "BRCA", "Method": "RBF Similarity", "Accuracy": 0.821, "F1 weighted": 0.810, "F1 macro": 0.745},
    {"Dataset": "BRCA", "Method": "RBF Distance", "Accuracy": 0.764, "F1 weighted": 0.764, "F1 macro": 0.671},
    {"Dataset": "BRCA", "Method": "Hybrid Similarity", "Accuracy": 0.764, "F1 weighted": 0.753, "F1 macro": 0.685},
    {"Dataset": "BRCA", "Method": "Hybrid Distance", "Accuracy": 0.776, "F1 weighted": 0.766, "F1 macro": 0.693}
]

data_rosmap = [ 
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.877, "F1": 0.876, "AUC": 0.902},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.821, "F1": 0.819, "AUC": 0.863},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.892},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.858, "F1": 0.860, "AUC": 0.871},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.881},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.830, "F1": 0.820, "AUC": 0.886}
]

# Preprocess
df_brca = pd.DataFrame(data_brca).rename(columns={"F1 weighted": "F1"})
df_rosmap = pd.DataFrame(data_rosmap)

# Combine
df_all = pd.concat([df_brca, df_rosmap], ignore_index=True)

# Melt into long format
df_long = df_all.melt(id_vars=["Dataset", "Method"], var_name="Metric", value_name="Score")

# Plot
sns.set(style="whitegrid", font_scale=1.1)
g = sns.catplot(
    data=df_long,
    x="Method", y="Score", hue="Dataset",
    col="Metric", kind="bar", height=5, aspect=1.1,
    palette="muted", dodge=True
)

g.set_titles(col_template="{col_name}")
g.set_xticklabels(rotation=20)
g.fig.subplots_adjust(top=0.85)
g.fig.suptitle("Cross-Dataset Performance Comparison", fontsize=25, weight='bold')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Data
data_brca = [ 
    {"Dataset": "BRCA", "Method": "Cosine Similarity", "Accuracy": 0.825, "F1 weighted": 0.817, "F1 macro": 0.766},
    {"Dataset": "BRCA", "Method": "Cosine Distance", "Accuracy": 0.783, "F1 weighted": 0.772, "F1 macro": 0.700},
    {"Dataset": "BRCA", "Method": "RBF Similarity", "Accuracy": 0.821, "F1 weighted": 0.810, "F1 macro": 0.745},
    {"Dataset": "BRCA", "Method": "RBF Distance", "Accuracy": 0.764, "F1 weighted": 0.764, "F1 macro": 0.671},
    {"Dataset": "BRCA", "Method": "Hybrid Similarity", "Accuracy": 0.764, "F1 weighted": 0.753, "F1 macro": 0.685},
    {"Dataset": "BRCA", "Method": "Hybrid Distance", "Accuracy": 0.776, "F1 weighted": 0.766, "F1 macro": 0.693}
]

data_rosmap = [ 
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.877, "F1": 0.876, "AUC": 0.902},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.821, "F1": 0.819, "AUC": 0.863},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.892},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.858, "F1": 0.860, "AUC": 0.871},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.881},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.830, "F1": 0.820, "AUC": 0.886}
]

# Preprocessing
df_brca = pd.DataFrame(data_brca).rename(columns={"F1 weighted": "F1"})
df_rosmap = pd.DataFrame(data_rosmap)

df_all = pd.concat([df_brca, df_rosmap], ignore_index=True)
df_long = df_all.melt(id_vars=["Dataset", "Method"], var_name="Metric", value_name="Score")

# Plot with 2 rows, 2 columns
sns.set(style="whitegrid", font_scale=1.1)
g = sns.catplot(
    data=df_long,
    x="Method", y="Score", hue="Dataset",
    col="Metric", kind="bar",
    height=4.5, aspect=1.2, col_wrap=2,
    palette="Set2", dodge=True
)

#g.set_titles("{col_name}", fontsize=12)
g.set_titles(col_template="{col_name}", fontsize=12)
g.set_xticklabels(rotation=20)
g.fig.subplots_adjust(top=0.88)
g.fig.suptitle("Cross-Dataset Metric Comparison for Similarity Networks", fontsize=14, weight='bold')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# --- DATA ---
data_brca = [ 
    {"Dataset": "BRCA", "Method": "Cosine Similarity", "Accuracy": 0.825, "F1 weighted": 0.817, "F1 macro": 0.766},
    {"Dataset": "BRCA", "Method": "Cosine Distance", "Accuracy": 0.783, "F1 weighted": 0.772, "F1 macro": 0.700},
    {"Dataset": "BRCA", "Method": "RBF Similarity", "Accuracy": 0.821, "F1 weighted": 0.810, "F1 macro": 0.745},
    {"Dataset": "BRCA", "Method": "RBF Distance", "Accuracy": 0.764, "F1 weighted": 0.764, "F1 macro": 0.671},
    {"Dataset": "BRCA", "Method": "Hybrid Similarity", "Accuracy": 0.764, "F1 weighted": 0.753, "F1 macro": 0.685},
    {"Dataset": "BRCA", "Method": "Hybrid Distance", "Accuracy": 0.776, "F1 weighted": 0.766, "F1 macro": 0.693}
]

data_rosmap = [ 
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.877, "F1": 0.876, "AUC": 0.902},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.821, "F1": 0.819, "AUC": 0.863},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.892},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.858, "F1": 0.860, "AUC": 0.871},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.881},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.830, "F1": 0.820, "AUC": 0.886}
]

# --- PROCESSING ---
# Normalize F1 column name for BRCA
df_brca = pd.DataFrame(data_brca).rename(columns={"F1 weighted": "F1"})
df_rosmap = pd.DataFrame(data_rosmap)

df_all = pd.concat([df_brca, df_rosmap], ignore_index=True)
df_long = df_all.melt(id_vars=["Dataset", "Method"], var_name="Metric", value_name="Score")

# --- PLOTTING ---
sns.set(style="whitegrid", font_scale=1.1)
g = sns.catplot(
    data=df_long,
    x="Method", y="Score", hue="Dataset",
    col="Metric", kind="point", 
    height=4.5, aspect=1.2, col_wrap=2,
    dodge=True, markers='o', linestyles='--',
    palette="tab10"
)

g.set_titles("{col_name}", fontsize=12)
g.set_xticklabels(rotation=20)
g.fig.subplots_adjust(top=0.88)
g.fig.suptitle("Point Plot: Cross-Dataset Similarity Network Comparison", fontsize=14, weight='bold')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Data setup
data_brca = [ 
    {"Dataset": "BRCA", "Method": "Cosine Similarity", "Accuracy": 0.825, "F1 weighted": 0.817, "F1 macro": 0.766},
    {"Dataset": "BRCA", "Method": "Cosine Distance", "Accuracy": 0.783, "F1 weighted": 0.772, "F1 macro": 0.700},
    {"Dataset": "BRCA", "Method": "RBF Similarity", "Accuracy": 0.821, "F1 weighted": 0.810, "F1 macro": 0.745},
    {"Dataset": "BRCA", "Method": "RBF Distance", "Accuracy": 0.764, "F1 weighted": 0.764, "F1 macro": 0.671},
    {"Dataset": "BRCA", "Method": "Hybrid Similarity", "Accuracy": 0.764, "F1 weighted": 0.753, "F1 macro": 0.685},
    {"Dataset": "BRCA", "Method": "Hybrid Distance", "Accuracy": 0.776, "F1 weighted": 0.766, "F1 macro": 0.693}
]

data_rosmap = [ 
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.877, "F1": 0.876, "AUC": 0.902},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.821, "F1": 0.819, "AUC": 0.863},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.892},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.858, "F1": 0.860, "AUC": 0.871},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.881},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.830, "F1": 0.820, "AUC": 0.886}
]

# Preprocessing
df_brca = pd.DataFrame(data_brca).rename(columns={"F1 weighted": "F1"})
df_rosmap = pd.DataFrame(data_rosmap)

df_all = pd.concat([df_brca, df_rosmap], ignore_index=True)
df_long = df_all.melt(id_vars=["Dataset", "Method"], var_name="Metric", value_name="Score")

# Plot
sns.set(style="whitegrid", font_scale=1.1)
g = sns.catplot(
    data=df_long,
    x="Method", y="Score", hue="Dataset",
    col="Metric", kind="bar",
    height=4.5, aspect=1.2, col_wrap=2,
    palette="Set2", dodge=True
)

# Fix x-tick labels visibility and angle
for ax in g.axes.flat:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=20, ha='right')
    ax.set_xlabel("Method")  # Explicitly set label to avoid hidden axis

g.set_titles(col_template="{col_name}", fontsize=12)
g.fig.subplots_adjust(top=0.88)
g.fig.suptitle("Cross-Dataset Metric Comparison for Similarity Networks", fontsize=14, weight='bold')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MBHS_PC\AppData\Local\Temp\ipykernel_17292\2821551643.py:43: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=20, ha='right')
# C:\Users\MBHS_PC\AppData\Local\Temp\ipykernel_17292\2821551643.py:43: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=20, ha='right')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Data
data_brca = [ 
    {"Dataset": "BRCA", "Method": "Cosine Similarity", "Accuracy": 0.825, "F1 weighted": 0.817, "F1 macro": 0.766},
    {"Dataset": "BRCA", "Method": "Cosine Distance", "Accuracy": 0.783, "F1 weighted": 0.772, "F1 macro": 0.700},
    {"Dataset": "BRCA", "Method": "RBF Similarity", "Accuracy": 0.821, "F1 weighted": 0.810, "F1 macro": 0.745},
    {"Dataset": "BRCA", "Method": "RBF Distance", "Accuracy": 0.764, "F1 weighted": 0.764, "F1 macro": 0.671},
    {"Dataset": "BRCA", "Method": "Hybrid Similarity", "Accuracy": 0.764, "F1 weighted": 0.753, "F1 macro": 0.685},
    {"Dataset": "BRCA", "Method": "Hybrid Distance", "Accuracy": 0.776, "F1 weighted": 0.766, "F1 macro": 0.693}
]

data_rosmap = [ 
    {"Dataset": "ROSMAP", "Method": "Cosine Similarity", "Accuracy": 0.877, "F1": 0.876, "AUC": 0.902},
    {"Dataset": "ROSMAP", "Method": "Cosine Distance", "Accuracy": 0.821, "F1": 0.819, "AUC": 0.863},
    {"Dataset": "ROSMAP", "Method": "RBF Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.892},
    {"Dataset": "ROSMAP", "Method": "RBF Distance", "Accuracy": 0.858, "F1": 0.860, "AUC": 0.871},
    {"Dataset": "ROSMAP", "Method": "Hybrid Similarity", "Accuracy": 0.849, "F1": 0.846, "AUC": 0.881},
    {"Dataset": "ROSMAP", "Method": "Hybrid Distance", "Accuracy": 0.830, "F1": 0.820, "AUC": 0.886}
]

# Preprocessing
df_brca = pd.DataFrame(data_brca).rename(columns={"F1 weighted": "F1"})
df_rosmap = pd.DataFrame(data_rosmap)

df_all = pd.concat([df_brca, df_rosmap], ignore_index=True)
df_long = df_all.melt(id_vars=["Dataset", "Method"], var_name="Metric", value_name="Score")

# Plot
sns.set(style="whitegrid", font_scale=1.1)
g = sns.catplot(
    data=df_long,
    x="Method", y="Score", hue="Dataset",
    col="Metric", kind="bar",
    height=4.5, aspect=1.2, col_wrap=2,
    palette="Set2", dodge=True
)

# FIX: Manually force tick locations and labels
for ax in g.axes.flat:
    labels = [tick.get_text() for tick in ax.get_xticklabels()]
    ax.xaxis.set_major_locator(ticker.FixedLocator(range(len(labels))))
    ax.set_xticklabels(labels, rotation=20, ha='right')
    ax.set_xlabel("Method")

g.set_titles(col_template="{col_name}", fontsize=12)
g.fig.subplots_adjust(top=0.88)
g.fig.suptitle("Cross-Dataset Metric Comparison for Similarity Networks", fontsize=14, weight='bold')
plt.tight_layout()
plt.show()

# %%
from PIL import Image
import os

def convert_to_tiff(folder_path):
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)

        # Skip if it's already a TIFF file
        if filename.lower().endswith((".tiff", ".tif")):
            print(f"ℹ️ Skipped (already TIFF): {filename}")
            continue

        try:
            with Image.open(file_path) as img:
                # Ensure RGB mode for consistency
                img = img.convert("RGB")
                
                # New TIFF file path
                tiff_path = os.path.splitext(file_path)[0] + ".tiff"
                
                # Save as TIFF
                img.save(tiff_path, "TIFF")
                os.remove(file_path)  # Optional: remove original file
                print(f"✅ Converted: {filename} → {os.path.basename(tiff_path)}")
        
        except Exception as e:
            print(f"❌ Failed to convert {filename}: {e}")

# 📂 Replace with your folder path
convert_to_tiff(r"D:\Masrafe\Masrafe extra\reasearch\mogonet\figure")
# Out:
# ✅ Converted: Fig 1. Methodological pipeline for multi-omics classification.png → Fig 1. Methodological pipeline for multi-omics classification.tiff
# ✅ Converted: Fig 2. Class label distribution for BRCA and ROSMAP datasets.png → Fig 2. Class label distribution for BRCA and ROSMAP datasets.tiff
# ✅ Converted: Fig 3. Feature preselection workflow.png → Fig 3. Feature preselection workflow.tiff
# ✅ Converted: Fig 4. Train–test data splitting strategy.png → Fig 4. Train–test data splitting strategy.tiff
# ✅ Converted: Fig 5. Performance metric visualization for the ROSMAP dataset across similarity network variants.png → Fig 5. Performance metric visualization for the ROSMAP dataset across similarity network variants.tiff
# ✅ Converted: Fig 6. Performance metric visualizations for the BRCA dataset across similarity network variants.png → Fig 6. Performance metric visualizations for the BRCA dataset across similarity network variants.tiff
# ...

# %%
from PIL import Image
import os

def convert_tiff_to_png(folder_path):
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)

        # Skip if it's already a PNG file
        if filename.lower().endswith(".png"):
            print(f"ℹ️ Skipped (already PNG): {filename}")
            continue

        # Process only TIFF files
        if not filename.lower().endswith((".tiff", ".tif")):
            print(f"⚠️ Skipped (not TIFF): {filename}")
            continue

        try:
            with Image.open(file_path) as img:
                # Convert to RGB to avoid palette issues
                img = img.convert("RGB")
                
                # New PNG file path
                png_path = os.path.splitext(file_path)[0] + ".png"
                
                # Save as PNG
                img.save(png_path, "PNG")
                os.remove(file_path)  # Optional: remove original file
                print(f"✅ Converted: {filename} → {os.path.basename(png_path)}")
        
        except Exception as e:
            print(f"❌ Failed to convert {filename}: {e}")

# 📂 Replace with your folder path
convert_tiff_to_png(r"D:\Masrafe\Masrafe extra\reasearch\mogonet\figure")
# Out:
# ✅ Converted: Bar_chart_comparison_for_both.tiff → Bar_chart_comparison_for_both.png
# ✅ Converted: Bar_Chart_of_AUC_varience_for_both.tiff → Bar_Chart_of_AUC_varience_for_both.png
# ✅ Converted: Class_labels_distribution_for_both_dataset.tiff → Class_labels_distribution_for_both_dataset.png
# ✅ Converted: Dataset_Distribution.tiff → Dataset_Distribution.png
# ✅ Converted: Heatmap_for_BRCA.tiff → Heatmap_for_BRCA.png
# ✅ Converted: Heatmap_for_ROSMP.tiff → Heatmap_for_ROSMP.png
# ✅ Converted: Line_chart_comparison_for_both.tiff → Line_chart_comparison_for_both.png
# ✅ Converted: Line_Chart_of_AUC_varience_for_both.tiff → Line_Chart_of_AUC_varience_for_both.png
# ✅ Converted: Methodology.tiff → Methodology.png
# ✅ Converted: Radar_plot_for_BRCA.tiff → Radar_plot_for_BRCA.png
# ✅ Converted: Radar_plot_for_ROSMAP.tiff → Radar_plot_for_ROSMAP.png
# ✅ Converted: Total_feature_for_both_dataset.tiff → Total_feature_for_both_dataset.png
# ...
